# %% [markdown]
# # Scraping the eCommerce Sellers Forum

# %% [markdown]
# link: https://forum.flowster.app/

# %% [markdown]
# ## First run: Explore using the inspector

# %%
from selenium.webdriver import Firefox
from selenium.webdriver.firefox.options import Options

opts = Options()
opts.set_headless()
assert opts.headless # Operating in headless mode
browser = Firefox(options=opts)
browser.get('https://forum.flowster.app/')
# Out:
# <ipython-input-31-0940fb2cc834>:5: DeprecationWarning: use setter for headless property instead of set_headless
#   opts.set_headless()

# %%
category_table = browser.find_elements_by_class_name('category-list')
print(category_table[0].text)
# Out:
# Category Topics
# Store & Website Management
# Have questions about Store & Website Management? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Product Detail Pages
# Copywriting
# Video & Photography
# Branding
# Payments & Fraud
# 2
# Product Sourcing
# Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Purchasing
# Sourcing Brand Name Products
# Vendor Management
# Pricing & Negotiation
# Vendor Relations
# Product Creation
# 57
# Management
# Have questions about Management? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Leadership
# Delegation
# 14
# Amazon Specific
# Have questions about using the Amazon marketplace? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Software & Tools
# All Other Amazon Related Issues
# PPC
# Reviews & Customer Service
# Inventory Management
# Pricing Management
# Product Prep
# 55
# Fulfillment
# Have questions about Fulfillment? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Shipping
# Third Party Fulfillment
# Warehouse Management
# 17
# Flowster-specific
# Discussion about Flowster, this Forum’s organization, and how we can improve it.
# Updates
# Free SOPs
# Marketplace
# 61
# eCommerce Marketplaces
# Have questions about sourcing the various sales channels available to you? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Amazon
# eBay
# Walmart
# Jet
# All Other Sales Channels
# 2
# Traffic Sources
# Have questions about generating traffic? Please be sure to select the most appropriate sub-category for your questions.
# Email Marketing
# PPC
# YouTube
# All Other Traffic Sources
# Facebook
# Facebook Messenger
# Google
# Instragram
# SEO
# Blogging & Content Marketing
# Kickstarter and Crowdfunding
# 7
# Software & Tools
# Have questions about Software & Tools? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Shopify
# Project Management
# Standard Operating Procedures
# SaaS Applications
# 14
# Financial Management
# Have questions about Financial Management? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Accounting & Bookkeeping
# Fundraising
# 7
# Human Resources
# Have questions about Human Resources? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Performance Reviews
# Recruiting
# Outsourcing
# Managing a Virtual Team
# Employee Onboarding
# Employee Termination
# 20
# Misc Topics
# Have questions about things that don’t fall under the other categories? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
# Networking & Events
# Education & Training
# Buying or Selling a Business
# Member Introductions
# Articles, Books, and Resources
# Product Launches
# Competitor Analysis
# Buy, Sell, and Trade Stuff
# 10

# %%
categories = browser.find_elements_by_class_name('category-text-title')
categories[0].text
# Out:
# 'Store & Website Management'

# %%
categ_links = browser.find_elements_by_css_selector('.category > h3 > a')
categ_links[0].get_attribute('href')
# Out:
# 'https://forum.flowster.app/c/store-website-management/40'

# %%
categ_names = []
categ_urls = []
for categ, link in zip(categories, categ_links):
    categ_names.append(categ.text)
    categ_urls.append(link.get_attribute('href'))

# %%
categ_names, categ_urls
# Out:
# (['Store & Website Management',
#   'Product Sourcing',
#   'Management',
#   'Amazon Specific',
#   'Fulfillment',
#   'Flowster-specific',
#   'eCommerce Marketplaces',
#   'Traffic Sources',
#   'Software & Tools',
#   'Financial Management',
#   'Human Resources',
#   'Misc Topics'],
#  ['https://forum.flowster.app/c/store-website-management/40',
#   'https://forum.flowster.app/c/product-sourcing/8',
#   'https://forum.flowster.app/c/management/32',
#   'https://forum.flowster.app/c/amazon-specific/17',
#   'https://forum.flowster.app/c/fulfillment/36',
#   'https://forum.flowster.app/c/flowster/2',
#   'https://forum.flowster.app/c/sales-channels/7',
#   'https://forum.flowster.app/c/traffic/13',
#   'https://forum.flowster.app/c/software-tools/26',
#   'https://forum.flowster.app/c/financial-management/21',
#   'https://forum.flowster.app/c/human-resources/46',
#   'https://forum.flowster.app/c/misc-topics/55'])

# %%
len(categ_names), len(categ_urls)
# Out:
# (12, 12)

# %% [markdown]
# - https://pythonbasics.org/selenium-scroll-down/
# - https://stackoverflow.com/questions/7263824/get-html-source-of-webelement-in-selenium-webdriver-using-python

# %%
import requests
import time

SEC_URL = categ_urls[1]
#page = requests.get(SEC_URL)
browser.get(SEC_URL)
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)

# %%
#print(page.content)
print(browser.page_source)
# Out:
# <html class="desktop-view not-mobile-device text-size-normal anon no-touch discourse-no-touch" lang="en-US"><head>
#     <meta charset="utf-8">
#     <title>Latest Product Sourcing topics - eCommerce Sellers Forum</title>
#     <meta name="description" content="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.">
#     <meta name="discourse_theme_ids" content="4">
#     <meta name="discourse_current_homepage" content="categories">
#     <meta name="generator" content="Discourse 2.6.0.beta5 - https://github.com/discourse/discourse version a17d54d0bf723683b57d79b0b21093d1b60d9454">
# <link rel="icon" type="image/png" href="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/optimized/1X/82825692ecfc5a07ad7eaf15a650ec2d37204805_2_32x32.png">
# <link rel="apple-touch-icon" type="image/png" href="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/optimized/1X/4bc9f285c064ed2e471ba63ed290d26ec7019f49_2_180x180.jpeg">
# <meta name="theme-color" content="#2363a0">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=yes, viewport-fit=cover">
# <link rel="canonical" href="https://forum.flowster.app/c/product-sourcing/8">
# <script async="" src="//www.google-analytics.com/analytics.js"></script><script type="text/javascript" async="" src="https://www.gstatic.com/recaptcha/releases/qc5B-qjP0QEimFYUxcpWJy5B/recaptcha__fr.js" crossorigin="anonymous" integrity="sha384-fTuMfAliJVfYh38oCRhSw4QBfBaXu/Y+0T66sUEM7g3gc2pgyM8jPbchfGYFatiP"></script><script type="application/ld+json">{"@context":"http://schema.org","@type":"WebSite","url":"https://forum.flowster.app","potentialAction":{"@type":"SearchAction","target":"https://forum.flowster.app/search?q={search_term_string}","query-input":"required name=search_term_string"}}</script>
# <link rel="search" type="application/opensearchdescription+xml" href="https://forum.flowster.app/opensearch.xml" title="eCommerce Sellers Forum Search">
#
#
#
#       <meta name="fragment" content="!">
#
#
#
#
#     <link rel="preload" href="/assets/browser-detect-115ab5953de1b5bb122bfb26b757f5391dd8d1d2aef2b81baf7b59aee99d9f34.js" as="script">
# <script src="/assets/browser-detect-115ab5953de1b5bb122bfb26b757f5391dd8d1d2aef2b81baf7b59aee99d9f34.js"></script>
#
#
#     <link rel="preload" href="/assets/locales/en_US-bab707662440d923ab0cd31b1499c3fdafb22f895eea42ac7818c59ebca46fb1.js" as="script">
# <script src="/assets/locales/en_US-bab707662440d923ab0cd31b1499c3fdafb22f895eea42ac7818c59ebca46fb1.js"></script>
#
#     <link rel="preload" href="/assets/ember_jquery-995fa9bf31464532692332d4a5c85988ebb80637550b8cd00f07d8953c4e46e5.js" as="script">
# <script src="/assets/ember_jquery-995fa9bf31464532692332d4a5c85988ebb80637550b8cd00f07d8953c4e46e5.js"></script>
#
#     <link rel="preload" href="/assets/vendor-a520d2facd37b23a6fce06beaf5feaa3034f761d5b4f37c89c4cecd3ead14192.js" as="script">
# <script src="/assets/vendor-a520d2facd37b23a6fce06beaf5feaa3034f761d5b4f37c89c4cecd3ead14192.js"></script>
#
#     <link rel="preload" href="/assets/pretty-text-bundle-a4b73e1a5b7ee9776b1eebacb87b9627e70b4df1c653239fc757bfbe4d75f3b4.js" as="script">
# <script src="/assets/pretty-text-bundle-a4b73e1a5b7ee9776b1eebacb87b9627e70b4df1c653239fc757bfbe4d75f3b4.js"></script>
#
#     <link rel="preload" href="/assets/application-cfe494512882a98ff913b63d6359a4246a9eb72e63b5a9121e12a61d02ddc4a0.js" as="script">
# <script src="/assets/application-cfe494512882a98ff913b63d6359a4246a9eb72e63b5a9121e12a61d02ddc4a0.js"></script>
#
#       <link rel="preload" href="/assets/plugins/discourse-details-9be9806ef2338ede8e5c567dfd5b521aaad27d01694f01c604516118466d2120.js" as="script">
# <script src="/assets/plugins/discourse-details-9be9806ef2338ede8e5c567dfd5b521aaad27d01694f01c604516118466d2120.js"></script>
#
#       <link rel="preload" href="/assets/plugins/discourse-local-dates-98d40cb865c9cedf395c459b9f45326b3a25198233a14b3556def275f82e8d36.js" as="script">
# <script src="/assets/plugins/discourse-local-dates-98d40cb865c9cedf395c459b9f45326b3a25198233a14b3556def275f82e8d36.js"></script>
#
#       <link rel="preload" href="/assets/plugins/discourse-narrative-bot-c43db87f1004dffa72bf81db5bfe561550f830b224352505680dde210d6ec6e1.js" as="script">
# <script src="/assets/plugins/discourse-narrative-bot-c43db87f1004dffa72bf81db5bfe561550f830b224352505680dde210d6ec6e1.js"></script>
#
#       <link rel="preload" href="/assets/plugins/discourse-presence-bce8f76d95606b6b412551e71dd8e087d8a89641a279304c6b1db45571047ae3.js" as="script">
# <script src="/assets/plugins/discourse-presence-bce8f76d95606b6b412551e71dd8e087d8a89641a279304c6b1db45571047ae3.js"></script>
#
#       <link rel="preload" href="/assets/plugins/docker_manager-4ced9f9c7bda9ba563c04006dbb93828d43f2c7d5b533065717c5a63da77d5fc.js" as="script">
# <script src="/assets/plugins/docker_manager-4ced9f9c7bda9ba563c04006dbb93828d43f2c7d5b533065717c5a63da77d5fc.js"></script>
#
#       <link rel="preload" href="/assets/plugins/lazy-yt-13878a92cc5d5039d6f32688a86500182843ceac829df20e96639d8026a65a8a.js" as="script">
# <script src="/assets/plugins/lazy-yt-13878a92cc5d5039d6f32688a86500182843ceac829df20e96639d8026a65a8a.js"></script>
#
#       <link rel="preload" href="/assets/plugins/poll-ddc71b1364fe11460ec4c29eef1df459dac0fd35221a6473ffbb5816db0ac510.js" as="script">
# <script src="/assets/plugins/poll-ddc71b1364fe11460ec4c29eef1df459dac0fd35221a6473ffbb5816db0ac510.js"></script>
#
#
#       <script src="/theme-javascripts/0433774381d142433fec062bdc8356cc3e86b097.js?__ws=forum.flowster.app"></script>
#
#
#
#
#
#
# <script src="/theme-javascripts/6c32544b587457d052c3b547f808bfdad152fe36.js?__ws=forum.flowster.app"></script>
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <script src="/theme-javascripts/b6311c89ad8d0469844a727ee7dd61a76cc4bf62.js?__ws=forum.flowster.app"></script>
#
#
#     <meta id="data-ga-universal-analytics" data-tracking-code="UA-124464104-2" data-json="{&quot;cookieDomain&quot;:&quot;auto&quot;}" data-auto-link-domains="">
#
# <link rel="preload" href="/assets/google-universal-analytics-706f1d28f0a97f67a47515c96189277240ec4940d968955042066d7873fd1fe8.js" as="script">
# <script src="/assets/google-universal-analytics-706f1d28f0a97f67a47515c96189277240ec4940d968955042066d7873fd1fe8.js"></script>
#
#
#     <link rel="manifest" href="/manifest.webmanifest" crossorigin="use-credentials">
#
#
#     <link href="/stylesheets/color_definitions_neutral_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet" class="light-scheme">
#
#   <link href="/stylesheets/desktop_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet" data-target="desktop" data-theme-id="4">
#
#
#   <link href="/stylesheets/discourse-details_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet" data-target="discourse-details" data-theme-id="4">
#   <link href="/stylesheets/discourse-local-dates_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet" data-target="discourse-local-dates" data-theme-id="4">
#   <link href="/stylesheets/discourse-presence_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet" data-target="discourse-presence" data-theme-id="4">
#   <link href="/stylesheets/lazy-yt_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet" data-target="lazy-yt" data-theme-id="4">
#   <link href="/stylesheets/poll_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet" data-target="poll" data-theme-id="4">
#   <link href="/stylesheets/poll_desktop_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet" data-target="poll_desktop" data-theme-id="4">
#
#   <link href="/stylesheets/desktop_theme_4_e3d09e8029537474351b611f9a7b3ecde9baf7da.css?__ws=forum.flowster.app" media="all" rel="stylesheet" data-target="desktop_theme" data-theme-id="4">
#
#
#
#         <link rel="next" href="/c/product-sourcing/8?page=1">
#     <link rel="alternate" type="application/rss+xml" title="Latest posts" href="https://forum.flowster.app/posts.rss">
#     <link rel="alternate" type="application/rss+xml" title="Latest topics" href="https://forum.flowster.app/latest.rss">
#     <link rel="alternate" type="application/rss+xml" title="RSS feed of topics in the 'Product Sourcing' category" href="https://forum.flowster.app/c/product-sourcing/8.rss">
#     <meta property="og:site_name" content="eCommerce Sellers Forum">
# <meta name="twitter:card" content="summary">
# <meta name="twitter:image" content="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/d9d77a4388bc4cf96f8de8d1a73370da4b34e1e2.png">
# <meta property="og:image" content="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/d9d77a4388bc4cf96f8de8d1a73370da4b34e1e2.png">
# <meta property="og:url" content="https://forum.flowster.app/c/product-sourcing/8">
# <meta name="twitter:url" content="https://forum.flowster.app/c/product-sourcing/8">
# <meta property="og:title" content="Product Sourcing">
# <meta name="twitter:title" content="Product Sourcing">
# <meta property="og:description" content="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.">
# <meta name="twitter:description" content="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.">
#
#
#
#
#     <meta id="data-discourse-setup" data-base-url="https://forum.flowster.app" data-base-uri="" data-environment="production" data-letter-avatar-version="5_70a404e2c8e633b245e797a566d32dc7" data-markdown-it-url="/assets/markdown-it-bundle-eb2d56e694ada56c74f860a116b5262e0e9759c99b3b44fb5eb4c96bdc751216.js" data-service-worker-url="service-worker-c8000968830b6f6bd33f1e842dffdd569664119d449f93dc7d428d963a71635d.js" data-default-locale="en_US" data-asset-version="80abcd2893ca15b5da77135ffb298636" data-disable-custom-css="false" data-highlight-js-path="/highlight-js/forum.flowster.app/1d5aed44039a872eadf84f24f60b2b7b0e066bae.js" data-svg-sprite-path="/svg-sprite/forum.flowster.app/svg-4-206e5bac4a8d008ee63054785c7e84d11c080a7f.js" data-enable-js-error-reporting="true" data-color-scheme-is-dark="false" data-user-color-scheme-id="3" data-user-dark-scheme-id="-1" data-s3-cdn="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com" data-s3-base-url="//flowster-discourse.sfo2.digitaloceanspaces.com">
#
#   <script src="/svg-sprite/forum.flowster.app/svg-4-206e5bac4a8d008ee63054785c7e84d11c080a7f.js"></script><style id="image-sizing-hack">#reply-control .d-editor-preview img:not(.thumbnail):not(.ytp-thumbnail-image), .cooked img:not(.thumbnail):not(.ytp-thumbnail-image) {max-width:690px;max-height:500px;}</style><script src="/javascripts/magnific-popup/1.1.0/jquery.magnific-popup.min.js"></script><script src="/highlight-js/forum.flowster.app/1d5aed44039a872eadf84f24f60b2b7b0e066bae.js"></script></head>
#
#   <body class="category category-product-sourcing docked">
#
#
#
#
#
#
#     <section id="main" class="ember-application">
#     <div class="ember-view" id="ember4"><!---->
# <!---->
# <div id="ember5" class="d-header-wrap ember-view"><header class="d-header clearfix"><div class="wrap"><div class="contents clearfix">
#     <div class="title"><a href="/" data-auto-route="true"><h1 id="site-text-logo" class="text-logo">eCommerce Sellers Forum</h1></a></div>
#     <div class="panel clearfix"><span class="header-buttons"><button class="widget-button btn btn-primary btn-small sign-up-button btn-text"><span class="d-button-label">Sign Up</span></button><button class="widget-button btn btn-primary btn-small login-button btn-icon-text"><svg class="fa d-icon d-icon-user svg-icon svg-node" aria-hidden="true"><use xlink:href="#user"></use></svg><span class="d-button-label">Log In</span></button></span><ul role="navigation" class="icons d-header-icons"><li class="header-dropdown-toggle search-dropdown"><a href="/search" data-auto-route="true" title="search topics, posts, users, or categories" aria-label="search topics, posts, users, or categories" id="search-button" class="icon btn-flat"><svg class="fa d-icon d-icon-search svg-icon svg-node" aria-hidden="true"><use xlink:href="#search"></use></svg></a></li><li class="header-dropdown-toggle hamburger-dropdown"><a href="" data-auto-route="true" title="go to another topic list or category" aria-label="go to another topic list or category" id="toggle-hamburger-menu" class="icon btn-flat"><svg class="fa d-icon d-icon-bars svg-icon svg-node" aria-hidden="true"><use xlink:href="#bars"></use></svg></a></li></ul></div>
#   </div></div></header></div>
#
# <!---->
#
# <div id="main-outlet" class="wrap" role="main">
#     <div id="ember7" class="above-main-container-outlet banner-themes ember-view">
# <!---->      <span id="ember8" class="ember-view">  <div id="ember10" class="custom-banner-outlet banner ember-view">
#   <div id="ember11" class="ember-view"><div class="banner-box"><div class="container"><div class="button-container"><button class="widget-button btn close btn-icon-text" aria-label="Close the banner" title="Close the banner"><svg class="fa d-icon d-icon-times svg-icon svg-node" aria-hidden="true"><use xlink:href="#times"></use></svg><span class="d-button-label">Close</span></button></div><div class="section-header"><div style="height:250px;">
#     <div class="flowster-banner-bg">
#         <h1 class="x-title">
#             Our Community of eCommerce Entrepreneurs
#         </h1>
#         <div class="colored-line"></div>
#         <div class="description" style="color:white; font-size:1.2em; max-width:600px;">
#             <p>
#                 Help each other to discover strategies and develop SOPs to ignite higher levels of growth, profitability, and operational efficiency.
#             </p>
#         </div>
#     </div>
# </div></div><div id="banner-content_wrap"><div class="row"></div></div></div></div></div>
# </div>
# </span>
# </div>
#
#   <div class="container">
#       <div id="ember12" class="ember-view"></div>
#     <div id="ember13" class="controls ember-view"><!----></div>
#     <div id="ember14" class="ember-view"><!----></div>
#     <div id="ember15" class="ember-view"><!----></div>
#     <div id="ember16" class="hidden create-topics-notice ember-view"><!----></div>
#     <!---->
#   </div>
#     <div class="container">
#     <div id="ember17" class="ember-view"><!----></div>
#     <div id="ember18" class="ember-view"><!----></div>
#   </div>
#
#   <div class="list-controls">
#     <div class="container">
#       <section id="ember19" class="navigation-container ember-view">  <div id="ember20" class="ember-view"></div>
#
#   <section class="category-heading">
# <!---->
#     <span id="ember21" class="ember-view"><!----></span>
#   </section>
#
#   <div class="category-navigation">
#     <ol id="ember23" class="category-breadcrumb ember-view">    <li id="ember25" class="select-kit single-select combobox combo-box category-drop has-selection bullet ember-view">  <div data-name="Product Sourcing" data-value="8" role="button" data-select-kit-id="ember25-header" aria-expanded="false" aria-haspopup="" aria-owns="[data-select-kit-id=ember25-body]" tabindex="0" id="ember26" class="select-kit-header single-select-header combo-box-header category-drop-header ember-view">  <div tabindex="0" title="Product Sourcing" data-value="8" data-name="Product Sourcing" class="select-kit-selected-name selected-name choice" data-ember-action="" data-ember-action-28="28">
# <!---->
#     <span class="name">
#       <span class="badge-wrapper bullet"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></span>
#     </span>
#
# <!---->  </div>
#
#
# <svg class="fa d-icon d-icon-caret-right svg-icon caret-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#caret-right"></use></svg>
# </div>
#
# <div data-select-kit-id="ember25-body" id="ember29" class="select-kit-body ember-view"><!----></div>
#   <div class="select-kit-wrapper"></div>
# </li>
#     <li id="ember31" class="select-kit single-select combobox combo-box category-drop bullet ember-view">  <div data-name="all" data-value="" role="button" data-select-kit-id="ember31-header" aria-expanded="false" aria-haspopup="" aria-owns="[data-select-kit-id=ember31-body]" tabindex="0" id="ember32" class="select-kit-header single-select-header combo-box-header category-drop-header ember-view">  <div tabindex="0" title="all" data-name="all" class="select-kit-selected-name selected-name choice" data-ember-action="" data-ember-action-34="34">
# <!---->
#     <span class="name">
#       all
#     </span>
#
# <!---->  </div>
#
#
# <svg class="fa d-icon d-icon-caret-right svg-icon caret-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#caret-right"></use></svg>
# </div>
#
# <div data-select-kit-id="ember31-body" id="ember35" class="select-kit-body ember-view"><!----></div>
#   <div class="select-kit-wrapper"></div>
# </li>
#
# <!---->
# <!---->
# </ol>
#
# <!---->
# <ul id="navigation-bar" class="nav nav-pills ember-view">  <li title="topics with recent posts" id="ember38" class="active ember-view"><a href="/c/product-sourcing/8/l/latest" class="active">
# <!---->  Latest
# </a>
# </li>
#   <li title="the most active topics in the last year, month, week or day" id="ember40" class="ember-view"><a href="/c/product-sourcing/8/l/top" class="">
# <!---->  Top
# </a>
# </li>
# <li id="ember41" class="ember-view"></li>
# <!----></ul>
#
# <!---->
# <span id="ember42" class="ember-view"><!----></span>
#
# <!---->
#
# <!---->
#
#     <span id="ember44" class="ember-view"><!----></span>
#   </div>
# </section>
#     </div>
#   </div>
#
#   <div id="ember45" class="loading-container ember-view">
# </div>
#
#   <span id="ember46" class="ember-view"><!----></span>
#
#   <div class="container list-container ">
#     <div class="row">
#       <div class="full-width">
#         <div id="header-list-area">
#           <!---->
#         </div>
#       </div>
#     </div>
#     <div class="row">
#       <div class="full-width">
#         <div id="list-area">
#           <span id="ember47" class="ember-view"><!----></span>
#           <!---->
# <!---->
# <!---->
# <div id="ember48" class="bulk-select-container ember-view" style="top: 27.0144px;"><!----></div>
#
# <div id="ember49" class="contents ember-view"><!---->  <span id="ember50" class="ember-view"><!----></span>
#
#     <table id="ember51" class="topic-list ember-view">  <thead>
#     <tr><th data-sort-order="default" class="default">Topic</th>
#
#   <th data-sort-order="posters" class="posters" aria-label="Posters"></th>
#
# <th data-sort-order="posts" class="posts sortable num">Replies</th>
#
# <th data-sort-order="views" class="views sortable num">Views</th>
#
# <th data-sort-order="activity" class="activity sortable num">Activity</th>
#
# </tr>
#   </thead>
#
# <!---->
#
# <tbody>
#     <tr data-topic-id="23" id="ember54" class="topic-list-item category-product-sourcing has-excerpt pinned ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><div class="topic-statuses">
# <span title="This topic is pinned for you; it will display at the top of its category" class="topic-status"><svg class="fa d-icon d-icon-thumbtack svg-icon pinned svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#thumbtack"></use></svg></span></div>
# <a href="/t/about-the-product-sourcing-category/23" class="title raw-link raw-topic-link" data-topic-id="23">About the Product Sourcing Category</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
#       <div class="topic-excerpt">
#     Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
#   </div>
#
# </td>
#
#   <td class="posters">
#     <a href="/u/trent-admin" data-user-card="Trent-Admin" class="latest single"><img alt="" src="/user_avatar/forum.flowster.app/trent-admin/25/10_2.png" class="avatar latest single" title="Trent-Admin - Original Poster, Most Recent Poster" aria-label="Trent-Admin - Original Poster, Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 0 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 0 replies">0</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 420 times">420</span></td>
#
# <td class="num age activity" title="First post: Apr 3, 2019 10:15 pm
# Posted: Apr 3, 2019 10:21 pm">
#   <a class="post-activity" href="/t/about-the-product-sourcing-category/23/1"><span class="relative-date with-year" data-time="1554326490937" data-format="tiny">Apr '19</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1534" id="ember56" class="topic-list-item category-product-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/virtual-assistant-sending-emails-hubspot/1534" class="title raw-link raw-topic-link" data-topic-id="1534">Virtual Assistant sending Emails Hubspot</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/grant" data-user-card="grant" class=""><img alt="" src="/letter_avatar_proxy/v4/letter/g/a5b964/25.png" class="avatar" title="grant - Original Poster" aria-label="grant - Original Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class="latest"><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar latest" title="Mitch - Most Recent Poster" aria-label="Mitch - Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 5 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 5 replies">5</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 78 times">78</span></td>
#
# <td class="num age activity" title="First post: Nov 18, 2020 9:12 pm
# Posted: Nov 19, 2020 10:47 pm">
#   <a class="post-activity" href="/t/virtual-assistant-sending-emails-hubspot/1534/6"><span class="relative-date" data-time="1605822460461" data-format="tiny">22d</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1510" id="ember58" class="topic-list-item category-product-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/china-sourcing/1510" class="title raw-link raw-topic-link" data-topic-id="1510">China sourcing</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/graceliang" data-user-card="GraceLiang" class=""><img alt="" src="/letter_avatar_proxy/v4/letter/g/e19adc/25.png" class="avatar" title="GraceLiang - Original Poster" aria-label="GraceLiang - Original Poster" width="25" height="25"></a>
#     <a href="/u/odellsuggs75" data-user-card="Odellsuggs75" class="latest"><img alt="" src="/letter_avatar_proxy/v4/letter/o/df705f/25.png" class="avatar latest" title="Odellsuggs75 - Most Recent Poster" aria-label="Odellsuggs75 - Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 3 replies">3</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 100 times">100</span></td>
#
# <td class="num age coldmap-low activity" title="First post: Oct 13, 2020 9:28 am
# Posted: Nov 6, 2020 5:56 am">
#   <a class="post-activity" href="/t/china-sourcing/1510/4"><span class="relative-date" data-time="1604638593917" data-format="tiny">Nov 6</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1507" id="ember60" class="topic-list-item category-product-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/virtual-assistant-using-email/1507" class="title raw-link raw-topic-link" data-topic-id="1507">Virtual Assistant Using Email</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/grant" data-user-card="grant" class="latest"><img alt="" src="/letter_avatar_proxy/v4/letter/g/a5b964/25.png" class="avatar latest" title="grant - Original Poster, Most Recent Poster" aria-label="grant - Original Poster, Most Recent Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class=""><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar" title="Mitch - Frequent Poster" aria-label="Mitch - Frequent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 4 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 4 replies">4</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 126 times">126</span></td>
#
# <td class="num age activity" title="First post: Oct 12, 2020 1:59 am
# Posted: Oct 13, 2020 7:26 pm">
#   <a class="post-activity" href="/t/virtual-assistant-using-email/1507/5"><span class="relative-date" data-time="1602613590972" data-format="tiny">Oct 13</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1508" id="ember62" class="topic-list-item category-product-sourcing-purchasing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/can-i-return-stock-that-doesnt-sell/1508" class="title raw-link raw-topic-link" data-topic-id="1508">Can I return stock that doesn’t sell?</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/purchasing/59"><span class="badge-category-parent-bg" style="background-color: #3AB54A;"></span><span class="badge-category-bg" style="background-color: #0088CC;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Let’s talk about purchasing products!"><span class="category-name">Purchasing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/malessa" data-user-card="Malessa" class="latest"><img alt="" src="/letter_avatar_proxy/v4/letter/m/c2a13f/25.png" class="avatar latest" title="Malessa - Original Poster, Most Recent Poster" aria-label="Malessa - Original Poster, Most Recent Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class=""><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar" title="Mitch - Frequent Poster" aria-label="Mitch - Frequent Poster" width="25" height="25"></a>
#     <a href="/u/grant" data-user-card="grant" class=""><img alt="" src="/letter_avatar_proxy/v4/letter/g/a5b964/25.png" class="avatar" title="grant - Frequent Poster" aria-label="grant - Frequent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 3 replies">3</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 60 times">60</span></td>
#
# <td class="num age activity" title="First post: Oct 12, 2020 8:34 am
# Posted: Oct 12, 2020 10:50 pm">
#   <a class="post-activity" href="/t/can-i-return-stock-that-doesnt-sell/1508/4"><span class="relative-date" data-time="1602539440216" data-format="tiny">Oct 12</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1468" id="ember64" class="topic-list-item category-product-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/how-to-get-a-reseller-permit-in-usa-as-a-canadian/1468" class="title raw-link raw-topic-link" data-topic-id="1468">How to get a Reseller Permit in USA as a Canadian?</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/wawaji" data-user-card="WawaJi" class=""><img alt="" src="/letter_avatar_proxy/v4/letter/w/ea666f/25.png" class="avatar" title="WawaJi - Original Poster" aria-label="WawaJi - Original Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class="latest"><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar latest" title="Mitch - Most Recent Poster" aria-label="Mitch - Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 3 replies">3</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 188 times">188</span></td>
#
# <td class="num age activity" title="First post: Aug 26, 2020 12:03 am
# Posted: Aug 27, 2020 1:49 pm">
#   <a class="post-activity" href="/t/how-to-get-a-reseller-permit-in-usa-as-a-canadian/1468/4"><span class="relative-date" data-time="1598532586214" data-format="tiny">Aug 27</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="831" id="ember66" class="topic-list-item category-product-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/video-in-your-email/831" class="title raw-link raw-topic-link" data-topic-id="831">Video in your Email</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/ben" data-user-card="Ben" class=""><img alt="" src="/user_avatar/forum.flowster.app/ben/25/236_2.png" class="avatar" title="Ben - Original Poster" aria-label="Ben - Original Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class=""><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar" title="Mitch - Frequent Poster" aria-label="Mitch - Frequent Poster" width="25" height="25"></a>
#     <a href="/u/keith4teamexi" data-user-card="Keith4TeamExi" class="latest"><img alt="" src="/user_avatar/forum.flowster.app/keith4teamexi/25/586_2.png" class="avatar latest" title="Keith4TeamExi - Most Recent Poster" aria-label="Keith4TeamExi - Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 4 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 4 replies">4</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 296 times">296</span></td>
#
# <td class="num age coldmap-high activity" title="First post: Aug 6, 2019 8:34 pm
# Posted: Jul 28, 2020 3:52 am">
#   <a class="post-activity" href="/t/video-in-your-email/831/5"><span class="relative-date" data-time="1595904776478" data-format="tiny">Jul 28</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1411" id="ember68" class="topic-list-item category-product-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/price-checker-2-competitor-storefront-extraction/1411" class="title raw-link raw-topic-link" data-topic-id="1411">Price Checker 2 - Competitor storefront extraction</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/moniqueandkerry" data-user-card="MoniqueAndKerry" class="latest"><img alt="" src="/user_avatar/forum.flowster.app/moniqueandkerry/25/573_2.png" class="avatar latest" title="MoniqueAndKerry - Original Poster, Most Recent Poster" aria-label="MoniqueAndKerry - Original Poster, Most Recent Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class=""><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar" title="Mitch - Frequent Poster" aria-label="Mitch - Frequent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 2 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 2 replies">2</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 269 times">269</span></td>
#
# <td class="num age activity" title="First post: Jun 8, 2020 9:02 am
# Posted: Jun 10, 2020 9:47 am">
#   <a class="post-activity" href="/t/price-checker-2-competitor-storefront-extraction/1411/3"><span class="relative-date" data-time="1591778834335" data-format="tiny">Jun 10</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1374" id="ember70" class="topic-list-item category-product-sourcing-purchasing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/top-10-tips-to-grow-your-business-rapidly/1374" class="title raw-link raw-topic-link" data-topic-id="1374">Top 10 Tips to Grow your Business Rapidly</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/purchasing/59"><span class="badge-category-parent-bg" style="background-color: #3AB54A;"></span><span class="badge-category-bg" style="background-color: #0088CC;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Let’s talk about purchasing products!"><span class="category-name">Purchasing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/pradimna_kumar" data-user-card="Pradimna_Kumar" class="latest single"><img alt="" src="/user_avatar/forum.flowster.app/pradimna_kumar/25/557_2.png" class="avatar latest single" title="Pradimna_Kumar - Original Poster, Most Recent Poster" aria-label="Pradimna_Kumar - Original Poster, Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 0 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 0 replies">0</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 216 times">216</span></td>
#
# <td class="num age activity" title="First post: May 12, 2020 9:16 am
# Posted: May 12, 2020 9:16 am">
#   <a class="post-activity" href="/t/top-10-tips-to-grow-your-business-rapidly/1374/1"><span class="relative-date" data-time="1589275015201" data-format="tiny">May 12</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1274" id="ember72" class="topic-list-item category-product-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/virtual-assistants/1274" class="title raw-link raw-topic-link" data-topic-id="1274">Virtual Assistants</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/mcdavid" data-user-card="McDavid" class=""><img alt="" src="/letter_avatar_proxy/v4/letter/m/b5a626/25.png" class="avatar" title="McDavid - Original Poster" aria-label="McDavid - Original Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class=""><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar" title="Mitch - Frequent Poster" aria-label="Mitch - Frequent Poster" width="25" height="25"></a>
#     <a href="/u/rebca" data-user-card="Rebca" class=""><img alt="" src="/user_avatar/forum.flowster.app/rebca/25/510_2.png" class="avatar" title="Rebca - Frequent Poster" aria-label="Rebca - Frequent Poster" width="25" height="25"></a>
#     <a href="/u/jimw_pb" data-user-card="JimW_PB" class="latest"><img alt="" src="/letter_avatar_proxy/v4/letter/j/ecccb3/25.png" class="avatar latest" title="JimW_PB - Most Recent Poster" aria-label="JimW_PB - Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 3 replies">3</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 302 times">302</span></td>
#
# <td class="num age activity" title="First post: Feb 20, 2020 12:06 am
# Posted: Feb 26, 2020 1:01 am">
#   <a class="post-activity" href="/t/virtual-assistants/1274/4"><span class="relative-date" data-time="1582675264916" data-format="tiny">Feb 26</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1272" id="ember74" class="topic-list-item category-product-sourcing-wholesale-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/can-you-sell-branded-products-on-amazon-uk/1272" class="title raw-link raw-topic-link" data-topic-id="1272">Can you sell branded products on Amazon uk</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/wholesale-sourcing/9"><span class="badge-category-parent-bg" style="background-color: #3AB54A;"></span><span class="badge-category-bg" style="background-color: #0088CC;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Posts about sourcing brand name products."><span class="category-name">Sourcing Brand Name Products</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/rameksuya" data-user-card="Rameksuya" class=""><img alt="" src="/letter_avatar_proxy/v4/letter/r/a4c791/25.png" class="avatar" title="Rameksuya - Original Poster" aria-label="Rameksuya - Original Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class="latest"><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar latest" title="Mitch - Most Recent Poster" aria-label="Mitch - Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 1 reply">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 1 reply">1</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 194 times">194</span></td>
#
# <td class="num age activity" title="First post: Feb 19, 2020 10:02 am
# Posted: Feb 19, 2020 4:06 pm">
#   <a class="post-activity" href="/t/can-you-sell-branded-products-on-amazon-uk/1272/2"><span class="relative-date" data-time="1582124788736" data-format="tiny">Feb 19</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1243" id="ember76" class="topic-list-item category-product-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/price-checker-sales-estimate/1243" class="title raw-link raw-topic-link" data-topic-id="1243">Price Checker Sales Estimate</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/xinod14" data-user-card="xinod14" class=""><img alt="" src="/user_avatar/forum.flowster.app/xinod14/25/402_2.png" class="avatar" title="xinod14 - Original Poster" aria-label="xinod14 - Original Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class="latest"><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar latest" title="Mitch - Most Recent Poster" aria-label="Mitch - Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 1 reply">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 1 reply">1</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 204 times">204</span></td>
#
# <td class="num age activity" title="First post: Feb 7, 2020 3:46 pm
# Posted: Feb 7, 2020 3:58 pm">
#   <a class="post-activity" href="/t/price-checker-sales-estimate/1243/2"><span class="relative-date" data-time="1581087490359" data-format="tiny">Feb 7</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1238" id="ember78" class="topic-list-item category-product-sourcing ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/black-box-amazon-product-research-yay-or-nay/1238" class="title raw-link raw-topic-link" data-topic-id="1238">Black Box (Amazon Product Research) - yay or nay?</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
#         <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span data-drop-close="true" class="badge-category clear-badge" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
#
#
#   </div>
# </td>
#
#   <td class="posters">
#     <a href="/u/zaid" data-user-card="zaid" class=""><img alt="" src="/letter_avatar_proxy/v4/letter/z/e95f7d/25.png" class="avatar" title="zaid - Original Poster" aria-label="zaid - Original Poster" width="25" height="25"></a>
#     <a href="/u/mitch" data-user-card="Mitch" class="latest"><img alt="" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" class="avatar latest" title="Mitch - Most Recent Poster" aria-label="Mitch - Most Recent Poster" width="25" height="25"></a>
# </td>
#
#
# <td class="num posts-map posts heatmap-" title="This topic has 1 reply">
#   <a href="" class="posts-map badge-posts heatmap-">
#
#     <span class="number" aria-label="This topic has 1 reply">1</span>
#   </a>
# </td>
#
#
#
#
# <td class="num views "><span class="number" title="this topic has been viewed 186 times">186</span></td>
#
# <td class="num age activity" title="First post: Feb 4, 2020 8:01 pm
# Posted: Feb 4, 2020 10:58 pm">
#   <a class="post-activity" href="/t/black-box-amazon-product-research-yay-or-nay/1238/2"><span class="relative-date" data-time="1580853498319" data-format="tiny">Feb 4</span></a>
# </td>
#
#
# </tr>
#     <!---->
#     <tr data-topic-id="1230" id="ember80" class="topic-list-item category-product-sourcing-vendor-management ember-view">
#
#
# <td class="main-link clearfix" colspan="1">
#   <span class="link-top-line"><a href="/t/vas-vs-outbound-call-center/1230" class="title raw-link raw-topic-link" data-topic-id="1230">VA’s vs Outbound Call Center</a><span class="topic-post-badges"></span>
#   </span>
#   <div class="link-bottom-line">
# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(browser.page_source, 'html.parser')

# %%
soup
# Out:
# <html class="desktop-view not-mobile-device text-size-normal anon no-touch discourse-no-touch" lang="en-US"><head>
# <meta charset="utf-8"/>
# <title>Latest Product Sourcing topics - eCommerce Sellers Forum</title>
# <meta content="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions." name="description"/>
# <meta content="4" name="discourse_theme_ids"/>
# <meta content="categories" name="discourse_current_homepage"/>
# <meta content="Discourse 2.6.0.beta5 - https://github.com/discourse/discourse version a17d54d0bf723683b57d79b0b21093d1b60d9454" name="generator"/>
# <link href="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/optimized/1X/82825692ecfc5a07ad7eaf15a650ec2d37204805_2_32x32.png" rel="icon" type="image/png"/>
# <link href="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/optimized/1X/4bc9f285c064ed2e471ba63ed290d26ec7019f49_2_180x180.jpeg" rel="apple-touch-icon" type="image/png"/>
# <meta content="#2363a0" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=yes, viewport-fit=cover" name="viewport"/>
# <link href="https://forum.flowster.app/c/product-sourcing/8" rel="canonical"/>
# <script async="" src="//www.google-analytics.com/analytics.js"></script><script async="" crossorigin="anonymous" integrity="sha384-fTuMfAliJVfYh38oCRhSw4QBfBaXu/Y+0T66sUEM7g3gc2pgyM8jPbchfGYFatiP" src="https://www.gstatic.com/recaptcha/releases/qc5B-qjP0QEimFYUxcpWJy5B/recaptcha__fr.js" type="text/javascript"></script><script type="application/ld+json">{"@context":"http://schema.org","@type":"WebSite","url":"https://forum.flowster.app","potentialAction":{"@type":"SearchAction","target":"https://forum.flowster.app/search?q={search_term_string}","query-input":"required name=search_term_string"}}</script>
# <link href="https://forum.flowster.app/opensearch.xml" rel="search" title="eCommerce Sellers Forum Search" type="application/opensearchdescription+xml"/>
# <meta content="!" name="fragment"/>
# <link as="script" href="/assets/browser-detect-115ab5953de1b5bb122bfb26b757f5391dd8d1d2aef2b81baf7b59aee99d9f34.js" rel="preload"/>
# <script src="/assets/browser-detect-115ab5953de1b5bb122bfb26b757f5391dd8d1d2aef2b81baf7b59aee99d9f34.js"></script>
# <link as="script" href="/assets/locales/en_US-bab707662440d923ab0cd31b1499c3fdafb22f895eea42ac7818c59ebca46fb1.js" rel="preload"/>
# <script src="/assets/locales/en_US-bab707662440d923ab0cd31b1499c3fdafb22f895eea42ac7818c59ebca46fb1.js"></script>
# <link as="script" href="/assets/ember_jquery-995fa9bf31464532692332d4a5c85988ebb80637550b8cd00f07d8953c4e46e5.js" rel="preload"/>
# <script src="/assets/ember_jquery-995fa9bf31464532692332d4a5c85988ebb80637550b8cd00f07d8953c4e46e5.js"></script>
# <link as="script" href="/assets/vendor-a520d2facd37b23a6fce06beaf5feaa3034f761d5b4f37c89c4cecd3ead14192.js" rel="preload"/>
# <script src="/assets/vendor-a520d2facd37b23a6fce06beaf5feaa3034f761d5b4f37c89c4cecd3ead14192.js"></script>
# <link as="script" href="/assets/pretty-text-bundle-a4b73e1a5b7ee9776b1eebacb87b9627e70b4df1c653239fc757bfbe4d75f3b4.js" rel="preload"/>
# <script src="/assets/pretty-text-bundle-a4b73e1a5b7ee9776b1eebacb87b9627e70b4df1c653239fc757bfbe4d75f3b4.js"></script>
# <link as="script" href="/assets/application-cfe494512882a98ff913b63d6359a4246a9eb72e63b5a9121e12a61d02ddc4a0.js" rel="preload"/>
# <script src="/assets/application-cfe494512882a98ff913b63d6359a4246a9eb72e63b5a9121e12a61d02ddc4a0.js"></script>
# <link as="script" href="/assets/plugins/discourse-details-9be9806ef2338ede8e5c567dfd5b521aaad27d01694f01c604516118466d2120.js" rel="preload"/>
# <script src="/assets/plugins/discourse-details-9be9806ef2338ede8e5c567dfd5b521aaad27d01694f01c604516118466d2120.js"></script>
# <link as="script" href="/assets/plugins/discourse-local-dates-98d40cb865c9cedf395c459b9f45326b3a25198233a14b3556def275f82e8d36.js" rel="preload"/>
# <script src="/assets/plugins/discourse-local-dates-98d40cb865c9cedf395c459b9f45326b3a25198233a14b3556def275f82e8d36.js"></script>
# <link as="script" href="/assets/plugins/discourse-narrative-bot-c43db87f1004dffa72bf81db5bfe561550f830b224352505680dde210d6ec6e1.js" rel="preload"/>
# <script src="/assets/plugins/discourse-narrative-bot-c43db87f1004dffa72bf81db5bfe561550f830b224352505680dde210d6ec6e1.js"></script>
# <link as="script" href="/assets/plugins/discourse-presence-bce8f76d95606b6b412551e71dd8e087d8a89641a279304c6b1db45571047ae3.js" rel="preload"/>
# <script src="/assets/plugins/discourse-presence-bce8f76d95606b6b412551e71dd8e087d8a89641a279304c6b1db45571047ae3.js"></script>
# <link as="script" href="/assets/plugins/docker_manager-4ced9f9c7bda9ba563c04006dbb93828d43f2c7d5b533065717c5a63da77d5fc.js" rel="preload"/>
# <script src="/assets/plugins/docker_manager-4ced9f9c7bda9ba563c04006dbb93828d43f2c7d5b533065717c5a63da77d5fc.js"></script>
# <link as="script" href="/assets/plugins/lazy-yt-13878a92cc5d5039d6f32688a86500182843ceac829df20e96639d8026a65a8a.js" rel="preload"/>
# <script src="/assets/plugins/lazy-yt-13878a92cc5d5039d6f32688a86500182843ceac829df20e96639d8026a65a8a.js"></script>
# <link as="script" href="/assets/plugins/poll-ddc71b1364fe11460ec4c29eef1df459dac0fd35221a6473ffbb5816db0ac510.js" rel="preload"/>
# <script src="/assets/plugins/poll-ddc71b1364fe11460ec4c29eef1df459dac0fd35221a6473ffbb5816db0ac510.js"></script>
# <script src="/theme-javascripts/0433774381d142433fec062bdc8356cc3e86b097.js?__ws=forum.flowster.app"></script>
# <script src="/theme-javascripts/6c32544b587457d052c3b547f808bfdad152fe36.js?__ws=forum.flowster.app"></script>
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <script src="/theme-javascripts/b6311c89ad8d0469844a727ee7dd61a76cc4bf62.js?__ws=forum.flowster.app"></script>
# <meta data-auto-link-domains="" data-json='{"cookieDomain":"auto"}' data-tracking-code="UA-124464104-2" id="data-ga-universal-analytics"/>
# <link as="script" href="/assets/google-universal-analytics-706f1d28f0a97f67a47515c96189277240ec4940d968955042066d7873fd1fe8.js" rel="preload"/>
# <script src="/assets/google-universal-analytics-706f1d28f0a97f67a47515c96189277240ec4940d968955042066d7873fd1fe8.js"></script>
# <link crossorigin="use-credentials" href="/manifest.webmanifest" rel="manifest"/>
# <link class="light-scheme" href="/stylesheets/color_definitions_neutral_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="desktop" data-theme-id="4" href="/stylesheets/desktop_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="discourse-details" data-theme-id="4" href="/stylesheets/discourse-details_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="discourse-local-dates" data-theme-id="4" href="/stylesheets/discourse-local-dates_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="discourse-presence" data-theme-id="4" href="/stylesheets/discourse-presence_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="lazy-yt" data-theme-id="4" href="/stylesheets/lazy-yt_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="poll" data-theme-id="4" href="/stylesheets/poll_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="poll_desktop" data-theme-id="4" href="/stylesheets/poll_desktop_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="desktop_theme" data-theme-id="4" href="/stylesheets/desktop_theme_4_e3d09e8029537474351b611f9a7b3ecde9baf7da.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link href="/c/product-sourcing/8?page=1" rel="next"/>
# <link href="https://forum.flowster.app/posts.rss" rel="alternate" title="Latest posts" type="application/rss+xml"/>
# <link href="https://forum.flowster.app/latest.rss" rel="alternate" title="Latest topics" type="application/rss+xml"/>
# <link href="https://forum.flowster.app/c/product-sourcing/8.rss" rel="alternate" title="RSS feed of topics in the 'Product Sourcing' category" type="application/rss+xml"/>
# <meta content="eCommerce Sellers Forum" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/d9d77a4388bc4cf96f8de8d1a73370da4b34e1e2.png" name="twitter:image"/>
# <meta content="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/d9d77a4388bc4cf96f8de8d1a73370da4b34e1e2.png" property="og:image"/>
# <meta content="https://forum.flowster.app/c/product-sourcing/8" property="og:url"/>
# <meta content="https://forum.flowster.app/c/product-sourcing/8" name="twitter:url"/>
# <meta content="Product Sourcing" property="og:title"/>
# <meta content="Product Sourcing" name="twitter:title"/>
# <meta content="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions." property="og:description"/>
# <meta content="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions." name="twitter:description"/>
# <meta data-asset-version="80abcd2893ca15b5da77135ffb298636" data-base-uri="" data-base-url="https://forum.flowster.app" data-color-scheme-is-dark="false" data-default-locale="en_US" data-disable-custom-css="false" data-enable-js-error-reporting="true" data-environment="production" data-highlight-js-path="/highlight-js/forum.flowster.app/1d5aed44039a872eadf84f24f60b2b7b0e066bae.js" data-letter-avatar-version="5_70a404e2c8e633b245e797a566d32dc7" data-markdown-it-url="/assets/markdown-it-bundle-eb2d56e694ada56c74f860a116b5262e0e9759c99b3b44fb5eb4c96bdc751216.js" data-s3-base-url="//flowster-discourse.sfo2.digitaloceanspaces.com" data-s3-cdn="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com" data-service-worker-url="service-worker-c8000968830b6f6bd33f1e842dffdd569664119d449f93dc7d428d963a71635d.js" data-svg-sprite-path="/svg-sprite/forum.flowster.app/svg-4-206e5bac4a8d008ee63054785c7e84d11c080a7f.js" data-user-color-scheme-id="3" data-user-dark-scheme-id="-1" id="data-discourse-setup"/>
# <script src="/svg-sprite/forum.flowster.app/svg-4-206e5bac4a8d008ee63054785c7e84d11c080a7f.js"></script><style id="image-sizing-hack">#reply-control .d-editor-preview img:not(.thumbnail):not(.ytp-thumbnail-image), .cooked img:not(.thumbnail):not(.ytp-thumbnail-image) {max-width:690px;max-height:500px;}</style><script src="/javascripts/magnific-popup/1.1.0/jquery.magnific-popup.min.js"></script><script src="/highlight-js/forum.flowster.app/1d5aed44039a872eadf84f24f60b2b7b0e066bae.js"></script></head>
# <body class="category category-product-sourcing docked">
# <section class="ember-application" id="main">
# <div class="ember-view" id="ember4"><!-- -->
# <!-- -->
# <div class="d-header-wrap ember-view" id="ember5"><header class="d-header clearfix"><div class="wrap"><div class="contents clearfix">
# <div class="title"><a data-auto-route="true" href="/"><h1 class="text-logo" id="site-text-logo">eCommerce Sellers Forum</h1></a></div>
# <div class="panel clearfix"><span class="header-buttons"><button class="widget-button btn btn-primary btn-small sign-up-button btn-text"><span class="d-button-label">Sign Up</span></button><button class="widget-button btn btn-primary btn-small login-button btn-icon-text"><svg aria-hidden="true" class="fa d-icon d-icon-user svg-icon svg-node"><use xlink:href="#user"></use></svg><span class="d-button-label">Log In</span></button></span><ul class="icons d-header-icons" role="navigation"><li class="header-dropdown-toggle search-dropdown"><a aria-label="search topics, posts, users, or categories" class="icon btn-flat" data-auto-route="true" href="/search" id="search-button" title="search topics, posts, users, or categories"><svg aria-hidden="true" class="fa d-icon d-icon-search svg-icon svg-node"><use xlink:href="#search"></use></svg></a></li><li class="header-dropdown-toggle hamburger-dropdown"><a aria-label="go to another topic list or category" class="icon btn-flat" data-auto-route="true" href="" id="toggle-hamburger-menu" title="go to another topic list or category"><svg aria-hidden="true" class="fa d-icon d-icon-bars svg-icon svg-node"><use xlink:href="#bars"></use></svg></a></li></ul></div>
# </div></div></header></div>
# <!-- -->
# <div class="wrap" id="main-outlet" role="main">
# <div class="above-main-container-outlet banner-themes ember-view" id="ember7">
# <!-- --> <span class="ember-view" id="ember8"> <div class="custom-banner-outlet banner ember-view" id="ember10">
# <div class="ember-view" id="ember11"><div class="banner-box"><div class="container"><div class="button-container"><button aria-label="Close the banner" class="widget-button btn close btn-icon-text" title="Close the banner"><svg aria-hidden="true" class="fa d-icon d-icon-times svg-icon svg-node"><use xlink:href="#times"></use></svg><span class="d-button-label">Close</span></button></div><div class="section-header"><div style="height:250px;">
# <div class="flowster-banner-bg">
# <h1 class="x-title">
#             Our Community of eCommerce Entrepreneurs
#         </h1>
# <div class="colored-line"></div>
# <div class="description" style="color:white; font-size:1.2em; max-width:600px;">
# <p>
#                 Help each other to discover strategies and develop SOPs to ignite higher levels of growth, profitability, and operational efficiency.
#             </p>
# </div>
# </div>
# </div></div><div id="banner-content_wrap"><div class="row"></div></div></div></div></div>
# </div>
# </span>
# </div>
# <div class="container">
# <div class="ember-view" id="ember12"></div>
# <div class="controls ember-view" id="ember13"><!-- --></div>
# <div class="ember-view" id="ember14"><!-- --></div>
# <div class="ember-view" id="ember15"><!-- --></div>
# <div class="hidden create-topics-notice ember-view" id="ember16"><!-- --></div>
# <!-- -->
# </div>
# <div class="container">
# <div class="ember-view" id="ember17"><!-- --></div>
# <div class="ember-view" id="ember18"><!-- --></div>
# </div>
# <div class="list-controls">
# <div class="container">
# <section class="navigation-container ember-view" id="ember19"> <div class="ember-view" id="ember20"></div>
# <section class="category-heading">
# <!-- -->
# <span class="ember-view" id="ember21"><!-- --></span>
# </section>
# <div class="category-navigation">
# <ol class="category-breadcrumb ember-view" id="ember23"> <li class="select-kit single-select combobox combo-box category-drop has-selection bullet ember-view" id="ember25"> <div aria-expanded="false" aria-haspopup="" aria-owns="[data-select-kit-id=ember25-body]" class="select-kit-header single-select-header combo-box-header category-drop-header ember-view" data-name="Product Sourcing" data-select-kit-id="ember25-header" data-value="8" id="ember26" role="button" tabindex="0"> <div class="select-kit-selected-name selected-name choice" data-ember-action="" data-ember-action-28="28" data-name="Product Sourcing" data-value="8" tabindex="0" title="Product Sourcing">
# <!-- -->
# <span class="name">
# <span class="badge-wrapper bullet"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></span>
# </span>
# <!-- --> </div>
# <svg class="fa d-icon d-icon-caret-right svg-icon caret-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#caret-right"></use></svg>
# </div>
# <div class="select-kit-body ember-view" data-select-kit-id="ember25-body" id="ember29"><!-- --></div>
# <div class="select-kit-wrapper"></div>
# </li>
# <li class="select-kit single-select combobox combo-box category-drop bullet ember-view" id="ember31"> <div aria-expanded="false" aria-haspopup="" aria-owns="[data-select-kit-id=ember31-body]" class="select-kit-header single-select-header combo-box-header category-drop-header ember-view" data-name="all" data-select-kit-id="ember31-header" data-value="" id="ember32" role="button" tabindex="0"> <div class="select-kit-selected-name selected-name choice" data-ember-action="" data-ember-action-34="34" data-name="all" tabindex="0" title="all">
# <!-- -->
# <span class="name">
#       all
#     </span>
# <!-- --> </div>
# <svg class="fa d-icon d-icon-caret-right svg-icon caret-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#caret-right"></use></svg>
# </div>
# <div class="select-kit-body ember-view" data-select-kit-id="ember31-body" id="ember35"><!-- --></div>
# <div class="select-kit-wrapper"></div>
# </li>
# <!-- -->
# <!-- -->
# </ol>
# <!-- -->
# <ul class="nav nav-pills ember-view" id="navigation-bar"> <li class="active ember-view" id="ember38" title="topics with recent posts"><a class="active" href="/c/product-sourcing/8/l/latest">
# <!-- -->  Latest
# </a>
# </li>
# <li class="ember-view" id="ember40" title="the most active topics in the last year, month, week or day"><a class="" href="/c/product-sourcing/8/l/top">
# <!-- -->  Top
# </a>
# </li>
# <li class="ember-view" id="ember41"></li>
# <!-- --></ul>
# <!-- -->
# <span class="ember-view" id="ember42"><!-- --></span>
# <!-- -->
# <!-- -->
# <span class="ember-view" id="ember44"><!-- --></span>
# </div>
# </section>
# </div>
# </div>
# <div class="loading-container ember-view" id="ember45">
# </div>
# <span class="ember-view" id="ember46"><!-- --></span>
# <div class="container list-container">
# <div class="row">
# <div class="full-width">
# <div id="header-list-area">
# <!-- -->
# </div>
# </div>
# </div>
# <div class="row">
# <div class="full-width">
# <div id="list-area">
# <span class="ember-view" id="ember47"><!-- --></span>
# <!-- -->
# <!-- -->
# <!-- -->
# <div class="bulk-select-container ember-view" id="ember48" style="top: 27.0144px;"><!-- --></div>
# <div class="contents ember-view" id="ember49"><!-- --> <span class="ember-view" id="ember50"><!-- --></span>
# <table class="topic-list ember-view" id="ember51"> <thead>
# <tr><th class="default" data-sort-order="default">Topic</th>
# <th aria-label="Posters" class="posters" data-sort-order="posters"></th>
# <th class="posts sortable num" data-sort-order="posts">Replies</th>
# <th class="views sortable num" data-sort-order="views">Views</th>
# <th class="activity sortable num" data-sort-order="activity">Activity</th>
# </tr>
# </thead>
# <!-- -->
# <tbody>
# <tr class="topic-list-item category-product-sourcing has-excerpt pinned ember-view" data-topic-id="23" id="ember54">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><div class="topic-statuses">
# <span class="topic-status" title="This topic is pinned for you; it will display at the top of its category"><svg class="fa d-icon d-icon-thumbtack svg-icon pinned svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#thumbtack"></use></svg></span></div>
# <a class="title raw-link raw-topic-link" data-topic-id="23" href="/t/about-the-product-sourcing-category/23">About the Product Sourcing Category</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# <div class="topic-excerpt">
#     Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions.
#   </div>
# </td>
# <td class="posters">
# <a class="latest single" data-user-card="Trent-Admin" href="/u/trent-admin"><img alt="" aria-label="Trent-Admin - Original Poster, Most Recent Poster" class="avatar latest single" height="25" src="/user_avatar/forum.flowster.app/trent-admin/25/10_2.png" title="Trent-Admin - Original Poster, Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 0 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 0 replies" class="number">0</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 420 times">420</span></td>
# <td class="num age activity" title="First post: Apr 3, 2019 10:15 pm
# Posted: Apr 3, 2019 10:21 pm">
# <a class="post-activity" href="/t/about-the-product-sourcing-category/23/1"><span class="relative-date with-year" data-format="tiny" data-time="1554326490937">Apr '19</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1534" id="ember56">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1534" href="/t/virtual-assistant-sending-emails-hubspot/1534">Virtual Assistant sending Emails Hubspot</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="" data-user-card="grant" href="/u/grant"><img alt="" aria-label="grant - Original Poster" class="avatar" height="25" src="/letter_avatar_proxy/v4/letter/g/a5b964/25.png" title="grant - Original Poster" width="25"/></a>
# <a class="latest" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Most Recent Poster" class="avatar latest" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 5 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 5 replies" class="number">5</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 78 times">78</span></td>
# <td class="num age activity" title="First post: Nov 18, 2020 9:12 pm
# Posted: Nov 19, 2020 10:47 pm">
# <a class="post-activity" href="/t/virtual-assistant-sending-emails-hubspot/1534/6"><span class="relative-date" data-format="tiny" data-time="1605822460461">22d</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1510" id="ember58">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1510" href="/t/china-sourcing/1510">China sourcing</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="" data-user-card="GraceLiang" href="/u/graceliang"><img alt="" aria-label="GraceLiang - Original Poster" class="avatar" height="25" src="/letter_avatar_proxy/v4/letter/g/e19adc/25.png" title="GraceLiang - Original Poster" width="25"/></a>
# <a class="latest" data-user-card="Odellsuggs75" href="/u/odellsuggs75"><img alt="" aria-label="Odellsuggs75 - Most Recent Poster" class="avatar latest" height="25" src="/letter_avatar_proxy/v4/letter/o/df705f/25.png" title="Odellsuggs75 - Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 3 replies" class="number">3</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 100 times">100</span></td>
# <td class="num age coldmap-low activity" title="First post: Oct 13, 2020 9:28 am
# Posted: Nov 6, 2020 5:56 am">
# <a class="post-activity" href="/t/china-sourcing/1510/4"><span class="relative-date" data-format="tiny" data-time="1604638593917">Nov 6</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1507" id="ember60">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1507" href="/t/virtual-assistant-using-email/1507">Virtual Assistant Using Email</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="latest" data-user-card="grant" href="/u/grant"><img alt="" aria-label="grant - Original Poster, Most Recent Poster" class="avatar latest" height="25" src="/letter_avatar_proxy/v4/letter/g/a5b964/25.png" title="grant - Original Poster, Most Recent Poster" width="25"/></a>
# <a class="" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Frequent Poster" class="avatar" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Frequent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 4 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 4 replies" class="number">4</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 126 times">126</span></td>
# <td class="num age activity" title="First post: Oct 12, 2020 1:59 am
# Posted: Oct 13, 2020 7:26 pm">
# <a class="post-activity" href="/t/virtual-assistant-using-email/1507/5"><span class="relative-date" data-format="tiny" data-time="1602613590972">Oct 13</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing-purchasing ember-view" data-topic-id="1508" id="ember62">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1508" href="/t/can-i-return-stock-that-doesnt-sell/1508">Can I return stock that doesn’t sell?</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/purchasing/59"><span class="badge-category-parent-bg" style="background-color: #3AB54A;"></span><span class="badge-category-bg" style="background-color: #0088CC;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Let’s talk about purchasing products!"><span class="category-name">Purchasing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="latest" data-user-card="Malessa" href="/u/malessa"><img alt="" aria-label="Malessa - Original Poster, Most Recent Poster" class="avatar latest" height="25" src="/letter_avatar_proxy/v4/letter/m/c2a13f/25.png" title="Malessa - Original Poster, Most Recent Poster" width="25"/></a>
# <a class="" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Frequent Poster" class="avatar" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Frequent Poster" width="25"/></a>
# <a class="" data-user-card="grant" href="/u/grant"><img alt="" aria-label="grant - Frequent Poster" class="avatar" height="25" src="/letter_avatar_proxy/v4/letter/g/a5b964/25.png" title="grant - Frequent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 3 replies" class="number">3</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 60 times">60</span></td>
# <td class="num age activity" title="First post: Oct 12, 2020 8:34 am
# Posted: Oct 12, 2020 10:50 pm">
# <a class="post-activity" href="/t/can-i-return-stock-that-doesnt-sell/1508/4"><span class="relative-date" data-format="tiny" data-time="1602539440216">Oct 12</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1468" id="ember64">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1468" href="/t/how-to-get-a-reseller-permit-in-usa-as-a-canadian/1468">How to get a Reseller Permit in USA as a Canadian?</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="" data-user-card="WawaJi" href="/u/wawaji"><img alt="" aria-label="WawaJi - Original Poster" class="avatar" height="25" src="/letter_avatar_proxy/v4/letter/w/ea666f/25.png" title="WawaJi - Original Poster" width="25"/></a>
# <a class="latest" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Most Recent Poster" class="avatar latest" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 3 replies" class="number">3</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 188 times">188</span></td>
# <td class="num age activity" title="First post: Aug 26, 2020 12:03 am
# Posted: Aug 27, 2020 1:49 pm">
# <a class="post-activity" href="/t/how-to-get-a-reseller-permit-in-usa-as-a-canadian/1468/4"><span class="relative-date" data-format="tiny" data-time="1598532586214">Aug 27</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="831" id="ember66">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="831" href="/t/video-in-your-email/831">Video in your Email</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="" data-user-card="Ben" href="/u/ben"><img alt="" aria-label="Ben - Original Poster" class="avatar" height="25" src="/user_avatar/forum.flowster.app/ben/25/236_2.png" title="Ben - Original Poster" width="25"/></a>
# <a class="" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Frequent Poster" class="avatar" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Frequent Poster" width="25"/></a>
# <a class="latest" data-user-card="Keith4TeamExi" href="/u/keith4teamexi"><img alt="" aria-label="Keith4TeamExi - Most Recent Poster" class="avatar latest" height="25" src="/user_avatar/forum.flowster.app/keith4teamexi/25/586_2.png" title="Keith4TeamExi - Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 4 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 4 replies" class="number">4</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 296 times">296</span></td>
# <td class="num age coldmap-high activity" title="First post: Aug 6, 2019 8:34 pm
# Posted: Jul 28, 2020 3:52 am">
# <a class="post-activity" href="/t/video-in-your-email/831/5"><span class="relative-date" data-format="tiny" data-time="1595904776478">Jul 28</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1411" id="ember68">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1411" href="/t/price-checker-2-competitor-storefront-extraction/1411">Price Checker 2 - Competitor storefront extraction</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="latest" data-user-card="MoniqueAndKerry" href="/u/moniqueandkerry"><img alt="" aria-label="MoniqueAndKerry - Original Poster, Most Recent Poster" class="avatar latest" height="25" src="/user_avatar/forum.flowster.app/moniqueandkerry/25/573_2.png" title="MoniqueAndKerry - Original Poster, Most Recent Poster" width="25"/></a>
# <a class="" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Frequent Poster" class="avatar" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Frequent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 2 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 2 replies" class="number">2</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 269 times">269</span></td>
# <td class="num age activity" title="First post: Jun 8, 2020 9:02 am
# Posted: Jun 10, 2020 9:47 am">
# <a class="post-activity" href="/t/price-checker-2-competitor-storefront-extraction/1411/3"><span class="relative-date" data-format="tiny" data-time="1591778834335">Jun 10</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing-purchasing ember-view" data-topic-id="1374" id="ember70">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1374" href="/t/top-10-tips-to-grow-your-business-rapidly/1374">Top 10 Tips to Grow your Business Rapidly</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/purchasing/59"><span class="badge-category-parent-bg" style="background-color: #3AB54A;"></span><span class="badge-category-bg" style="background-color: #0088CC;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Let’s talk about purchasing products!"><span class="category-name">Purchasing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="latest single" data-user-card="Pradimna_Kumar" href="/u/pradimna_kumar"><img alt="" aria-label="Pradimna_Kumar - Original Poster, Most Recent Poster" class="avatar latest single" height="25" src="/user_avatar/forum.flowster.app/pradimna_kumar/25/557_2.png" title="Pradimna_Kumar - Original Poster, Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 0 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 0 replies" class="number">0</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 216 times">216</span></td>
# <td class="num age activity" title="First post: May 12, 2020 9:16 am
# Posted: May 12, 2020 9:16 am">
# <a class="post-activity" href="/t/top-10-tips-to-grow-your-business-rapidly/1374/1"><span class="relative-date" data-format="tiny" data-time="1589275015201">May 12</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1274" id="ember72">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1274" href="/t/virtual-assistants/1274">Virtual Assistants</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="" data-user-card="McDavid" href="/u/mcdavid"><img alt="" aria-label="McDavid - Original Poster" class="avatar" height="25" src="/letter_avatar_proxy/v4/letter/m/b5a626/25.png" title="McDavid - Original Poster" width="25"/></a>
# <a class="" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Frequent Poster" class="avatar" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Frequent Poster" width="25"/></a>
# <a class="" data-user-card="Rebca" href="/u/rebca"><img alt="" aria-label="Rebca - Frequent Poster" class="avatar" height="25" src="/user_avatar/forum.flowster.app/rebca/25/510_2.png" title="Rebca - Frequent Poster" width="25"/></a>
# <a class="latest" data-user-card="JimW_PB" href="/u/jimw_pb"><img alt="" aria-label="JimW_PB - Most Recent Poster" class="avatar latest" height="25" src="/letter_avatar_proxy/v4/letter/j/ecccb3/25.png" title="JimW_PB - Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 3 replies" class="number">3</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 302 times">302</span></td>
# <td class="num age activity" title="First post: Feb 20, 2020 12:06 am
# Posted: Feb 26, 2020 1:01 am">
# <a class="post-activity" href="/t/virtual-assistants/1274/4"><span class="relative-date" data-format="tiny" data-time="1582675264916">Feb 26</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing-wholesale-sourcing ember-view" data-topic-id="1272" id="ember74">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1272" href="/t/can-you-sell-branded-products-on-amazon-uk/1272">Can you sell branded products on Amazon uk</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/wholesale-sourcing/9"><span class="badge-category-parent-bg" style="background-color: #3AB54A;"></span><span class="badge-category-bg" style="background-color: #0088CC;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Posts about sourcing brand name products."><span class="category-name">Sourcing Brand Name Products</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="" data-user-card="Rameksuya" href="/u/rameksuya"><img alt="" aria-label="Rameksuya - Original Poster" class="avatar" height="25" src="/letter_avatar_proxy/v4/letter/r/a4c791/25.png" title="Rameksuya - Original Poster" width="25"/></a>
# <a class="latest" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Most Recent Poster" class="avatar latest" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 1 reply">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 1 reply" class="number">1</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 194 times">194</span></td>
# <td class="num age activity" title="First post: Feb 19, 2020 10:02 am
# Posted: Feb 19, 2020 4:06 pm">
# <a class="post-activity" href="/t/can-you-sell-branded-products-on-amazon-uk/1272/2"><span class="relative-date" data-format="tiny" data-time="1582124788736">Feb 19</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1243" id="ember76">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1243" href="/t/price-checker-sales-estimate/1243">Price Checker Sales Estimate</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="" data-user-card="xinod14" href="/u/xinod14"><img alt="" aria-label="xinod14 - Original Poster" class="avatar" height="25" src="/user_avatar/forum.flowster.app/xinod14/25/402_2.png" title="xinod14 - Original Poster" width="25"/></a>
# <a class="latest" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Most Recent Poster" class="avatar latest" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 1 reply">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 1 reply" class="number">1</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 204 times">204</span></td>
# <td class="num age activity" title="First post: Feb 7, 2020 3:46 pm
# Posted: Feb 7, 2020 3:58 pm">
# <a class="post-activity" href="/t/price-checker-sales-estimate/1243/2"><span class="relative-date" data-format="tiny" data-time="1581087490359">Feb 7</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1238" id="ember78">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1238" href="/t/black-box-amazon-product-research-yay-or-nay/1238">Black Box (Amazon Product Research) - yay or nay?</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="" data-user-card="zaid" href="/u/zaid"><img alt="" aria-label="zaid - Original Poster" class="avatar" height="25" src="/letter_avatar_proxy/v4/letter/z/e95f7d/25.png" title="zaid - Original Poster" width="25"/></a>
# <a class="latest" data-user-card="Mitch" href="/u/mitch"><img alt="" aria-label="Mitch - Most Recent Poster" class="avatar latest" height="25" src="/user_avatar/forum.flowster.app/mitch/25/35_2.png" title="Mitch - Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 1 reply">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 1 reply" class="number">1</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 186 times">186</span></td>
# <td class="num age activity" title="First post: Feb 4, 2020 8:01 pm
# Posted: Feb 4, 2020 10:58 pm">
# <a class="post-activity" href="/t/black-box-amazon-product-research-yay-or-nay/1238/2"><span class="relative-date" data-format="tiny" data-time="1580853498319">Feb 4</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing-vendor-management ember-view" data-topic-id="1230" id="ember80">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1230" href="/t/vas-vs-outbound-call-center/1230">VA’s vs Outbound Call Center</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/vendor-management/54"><span class="badge-category-parent-bg" style="background-color: #3AB54A;"></span><span class="badge-category-bg" style="background-color: #0088CC;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Posts about vendor (supplier) management."><span class="category-name">Vendor Management</span></span></a>
# </div>
# </td>
# <td class="posters">
# <a class="latest single" data-user-card="Daniel_Folkmanas" href="/u/daniel_folkmanas"><img alt="" aria-label="Daniel_Folkmanas - Original Poster, Most Recent Poster" class="avatar latest single" height="25" src="/user_avatar/forum.flowster.app/daniel_folkmanas/25/326_2.png" title="Daniel_Folkmanas - Original Poster, Most Recent Poster" width="25"/></a>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 0 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 0 replies" class="number">0</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 196 times">196</span></td>
# <td class="num age activity" title="First post: Jan 30, 2020 2:07 am
# Posted: Jan 30, 2020 2:07 am">
# <a class="post-activity" href="/t/vas-vs-outbound-call-center/1230/1"><span class="relative-date" data-format="tiny" data-time="1580346427284">Jan 30</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1218" id="ember82">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1218" href="/t/bos-contact-info-research-linkedin-paid-account-va-access/1218">BO’s Contact Info Research Linkedin paid account VA access</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# ...
# </symbol><symbol id="thermometer-three-quarters" viewbox="0 0 256 512">
# <path d="M192 384c0 35.346-28.654 64-64 64-35.346 0-64-28.654-64-64 0-23.685 12.876-44.349 32-55.417V160c0-17.673 14.327-32 32-32s32 14.327 32 32v168.583c19.124 11.068 32 31.732 32 55.417zm32-84.653c19.912 22.563 32 52.194 32 84.653 0 70.696-57.303 128-128 128-.299 0-.609-.001-.909-.003C56.789 511.509-.357 453.636.002 383.333.166 351.135 12.225 321.755 32 299.347V96c0-53.019 42.981-96 96-96s96 42.981 96 96v203.347zM208 384c0-34.339-19.37-52.19-32-66.502V96c0-26.467-21.533-48-48-48S80 69.533 80 96v221.498c-12.732 14.428-31.825 32.1-31.999 66.08-.224 43.876 35.563 80.116 79.423 80.42L128 464c44.112 0 80-35.888 80-80z"></path>
# </symbol><symbol id="thumbs-down" viewbox="0 0 512 512">
# <path d="M0 56v240c0 13.255 10.745 24 24 24h80c13.255 0 24-10.745 24-24V56c0-13.255-10.745-24-24-24H24C10.745 32 0 42.745 0 56zm40 200c0-13.255 10.745-24 24-24s24 10.745 24 24-10.745 24-24 24-24-10.745-24-24zm272 256c-20.183 0-29.485-39.293-33.931-57.795-5.206-21.666-10.589-44.07-25.393-58.902-32.469-32.524-49.503-73.967-89.117-113.111a11.98 11.98 0 0 1-3.558-8.521V59.901c0-6.541 5.243-11.878 11.783-11.998 15.831-.29 36.694-9.079 52.651-16.178C256.189 17.598 295.709.017 343.995 0h2.844c42.777 0 93.363.413 113.774 29.737 8.392 12.057 10.446 27.034 6.148 44.632 16.312 17.053 25.063 48.863 16.382 74.757 17.544 23.432 19.143 56.132 9.308 79.469l.11.11c11.893 11.949 19.523 31.259 19.439 49.197-.156 30.352-26.157 58.098-59.553 58.098H350.723C358.03 364.34 384 388.132 384 430.548 384 504 336 512 312 512z"></path>
# <path d="M442.7 396.2L36.5 70.7c-6.9-5.5-17-4.4-22.5 2.5L4 85.6c-5.5 6.9-4.4 17 2.5 22.5l406.2 325.5c6.9 5.5 17 4.4 22.5-2.5l10-12.5c5.5-6.9 3.7-17.7-3.2-23.2l.7.8zM67.5 368c16.7-22 34.5-55.8 41.4-110.6l-45.5-35.6C60.2 312.6 27 342.5 8.6 362.3 2.6 368.7 0 376.4 0 384c.1 16.4 13 32 32.1 32h279.7l-61.4-48H67.5zM224 96c61.9 0 112 50.1 112 112 0 .2-.1.4-.1.6 0 16.8 1.2 31.8 2.8 45.7l59.5 46.5c-8.3-22.1-14.3-51.5-14.3-92.9 0-77.7-54.5-139.9-127.9-155.2V32c0-17.7-14.3-32-32-32s-32 14.3-32 32v20.8c-26 5.4-49.4 16.9-69.1 32.7l38.2 29.8C179 103.2 200.6 96 224 96zm0 416c35.3 0 64-28.6 64-64H160c0 35.4 28.7 64 64 64z"></path>
# </symbol></svg></div></div></body></html>

# %%
ps_topic_link = soup.find_all('a', class_='title raw-link raw-topic-link')[0]['href']

# %%
ps_topic_link
# Out:
# '/t/about-the-product-sourcing-category/23'

# %%
ps_topic_links = soup.find_all('a', class_='title raw-link raw-topic-link')

# %%
len(ps_topic_links)
# Out:
# 58

# %%
ps_topic_links[0]['href']
# Out:
# '/t/about-the-product-sourcing-category/23'

# %%
ps_topic_urls = []
BASE_URL = 'https://forum.flowster.app'
for topic_link in ps_topic_links:
    ps_topic_urls.append(BASE_URL + topic_link['href'])

# %%
len(ps_topic_urls)
# Out:
# 58

# %%
ps_topic_urls[0]
# Out:
# 'https://forum.flowster.app/t/about-the-product-sourcing-category/23'

# %%
PS_URL0 = ps_topic_urls[1]
browser.get(PS_URL0)
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)

# %%
from bs4 import BeautifulSoup

ps_soup = BeautifulSoup(browser.page_source, 'html.parser')

# %%
ps_soup
# Out:
# <html class="desktop-view not-mobile-device text-size-normal anon no-touch discourse-no-touch" lang="en-US"><head>
# <meta charset="utf-8"/>
# <title>Virtual Assistant sending Emails Hubspot - Product Sourcing - eCommerce Sellers Forum</title>
# <meta content="Hello Bright Ideas Tribe,
# I would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspo&amp;hellip;" name="description"/>
# <meta content="4" name="discourse_theme_ids"/>
# <meta content="categories" name="discourse_current_homepage"/>
# <meta content="Discourse 2.6.0.beta5 - https://github.com/discourse/discourse version a17d54d0bf723683b57d79b0b21093d1b60d9454" name="generator"/>
# <link href="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/optimized/1X/82825692ecfc5a07ad7eaf15a650ec2d37204805_2_32x32.png" rel="icon" type="image/png"/>
# <link href="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/optimized/1X/4bc9f285c064ed2e471ba63ed290d26ec7019f49_2_180x180.jpeg" rel="apple-touch-icon" type="image/png"/>
# <meta content="#2363a0" name="theme-color"/>
# <meta content="width=device-width, initial-scale=1.0, minimum-scale=1.0, user-scalable=yes, viewport-fit=cover" name="viewport"/>
# <link href="https://forum.flowster.app/t/virtual-assistant-sending-emails-hubspot/1534" rel="canonical"/>
# <script async="" src="//www.google-analytics.com/analytics.js"></script><script async="" crossorigin="anonymous" integrity="sha384-fTuMfAliJVfYh38oCRhSw4QBfBaXu/Y+0T66sUEM7g3gc2pgyM8jPbchfGYFatiP" src="https://www.gstatic.com/recaptcha/releases/qc5B-qjP0QEimFYUxcpWJy5B/recaptcha__fr.js" type="text/javascript"></script><script type="application/ld+json">{"@context":"http://schema.org","@type":"WebSite","url":"https://forum.flowster.app","potentialAction":{"@type":"SearchAction","target":"https://forum.flowster.app/search?q={search_term_string}","query-input":"required name=search_term_string"}}</script>
# <link href="https://forum.flowster.app/opensearch.xml" rel="search" title="eCommerce Sellers Forum Search" type="application/opensearchdescription+xml"/>
# <meta content="!" name="fragment"/>
# <link as="script" href="/assets/browser-detect-115ab5953de1b5bb122bfb26b757f5391dd8d1d2aef2b81baf7b59aee99d9f34.js" rel="preload"/>
# <script src="/assets/browser-detect-115ab5953de1b5bb122bfb26b757f5391dd8d1d2aef2b81baf7b59aee99d9f34.js"></script>
# <link as="script" href="/assets/locales/en_US-bab707662440d923ab0cd31b1499c3fdafb22f895eea42ac7818c59ebca46fb1.js" rel="preload"/>
# <script src="/assets/locales/en_US-bab707662440d923ab0cd31b1499c3fdafb22f895eea42ac7818c59ebca46fb1.js"></script>
# <link as="script" href="/assets/ember_jquery-995fa9bf31464532692332d4a5c85988ebb80637550b8cd00f07d8953c4e46e5.js" rel="preload"/>
# <script src="/assets/ember_jquery-995fa9bf31464532692332d4a5c85988ebb80637550b8cd00f07d8953c4e46e5.js"></script>
# <link as="script" href="/assets/vendor-a520d2facd37b23a6fce06beaf5feaa3034f761d5b4f37c89c4cecd3ead14192.js" rel="preload"/>
# <script src="/assets/vendor-a520d2facd37b23a6fce06beaf5feaa3034f761d5b4f37c89c4cecd3ead14192.js"></script>
# <link as="script" href="/assets/pretty-text-bundle-a4b73e1a5b7ee9776b1eebacb87b9627e70b4df1c653239fc757bfbe4d75f3b4.js" rel="preload"/>
# <script src="/assets/pretty-text-bundle-a4b73e1a5b7ee9776b1eebacb87b9627e70b4df1c653239fc757bfbe4d75f3b4.js"></script>
# <link as="script" href="/assets/application-cfe494512882a98ff913b63d6359a4246a9eb72e63b5a9121e12a61d02ddc4a0.js" rel="preload"/>
# <script src="/assets/application-cfe494512882a98ff913b63d6359a4246a9eb72e63b5a9121e12a61d02ddc4a0.js"></script>
# <link as="script" href="/assets/plugins/discourse-details-9be9806ef2338ede8e5c567dfd5b521aaad27d01694f01c604516118466d2120.js" rel="preload"/>
# <script src="/assets/plugins/discourse-details-9be9806ef2338ede8e5c567dfd5b521aaad27d01694f01c604516118466d2120.js"></script>
# <link as="script" href="/assets/plugins/discourse-local-dates-98d40cb865c9cedf395c459b9f45326b3a25198233a14b3556def275f82e8d36.js" rel="preload"/>
# <script src="/assets/plugins/discourse-local-dates-98d40cb865c9cedf395c459b9f45326b3a25198233a14b3556def275f82e8d36.js"></script>
# <link as="script" href="/assets/plugins/discourse-narrative-bot-c43db87f1004dffa72bf81db5bfe561550f830b224352505680dde210d6ec6e1.js" rel="preload"/>
# <script src="/assets/plugins/discourse-narrative-bot-c43db87f1004dffa72bf81db5bfe561550f830b224352505680dde210d6ec6e1.js"></script>
# <link as="script" href="/assets/plugins/discourse-presence-bce8f76d95606b6b412551e71dd8e087d8a89641a279304c6b1db45571047ae3.js" rel="preload"/>
# <script src="/assets/plugins/discourse-presence-bce8f76d95606b6b412551e71dd8e087d8a89641a279304c6b1db45571047ae3.js"></script>
# <link as="script" href="/assets/plugins/docker_manager-4ced9f9c7bda9ba563c04006dbb93828d43f2c7d5b533065717c5a63da77d5fc.js" rel="preload"/>
# <script src="/assets/plugins/docker_manager-4ced9f9c7bda9ba563c04006dbb93828d43f2c7d5b533065717c5a63da77d5fc.js"></script>
# <link as="script" href="/assets/plugins/lazy-yt-13878a92cc5d5039d6f32688a86500182843ceac829df20e96639d8026a65a8a.js" rel="preload"/>
# <script src="/assets/plugins/lazy-yt-13878a92cc5d5039d6f32688a86500182843ceac829df20e96639d8026a65a8a.js"></script>
# <link as="script" href="/assets/plugins/poll-ddc71b1364fe11460ec4c29eef1df459dac0fd35221a6473ffbb5816db0ac510.js" rel="preload"/>
# <script src="/assets/plugins/poll-ddc71b1364fe11460ec4c29eef1df459dac0fd35221a6473ffbb5816db0ac510.js"></script>
# <script src="/theme-javascripts/0433774381d142433fec062bdc8356cc3e86b097.js?__ws=forum.flowster.app"></script>
# <script src="/theme-javascripts/6c32544b587457d052c3b547f808bfdad152fe36.js?__ws=forum.flowster.app"></script>
# <script src="https://www.google.com/recaptcha/api.js"></script>
# <script src="/theme-javascripts/b6311c89ad8d0469844a727ee7dd61a76cc4bf62.js?__ws=forum.flowster.app"></script>
# <meta data-auto-link-domains="" data-json='{"cookieDomain":"auto"}' data-tracking-code="UA-124464104-2" id="data-ga-universal-analytics"/>
# <link as="script" href="/assets/google-universal-analytics-706f1d28f0a97f67a47515c96189277240ec4940d968955042066d7873fd1fe8.js" rel="preload"/>
# <script src="/assets/google-universal-analytics-706f1d28f0a97f67a47515c96189277240ec4940d968955042066d7873fd1fe8.js"></script>
# <link crossorigin="use-credentials" href="/manifest.webmanifest" rel="manifest"/>
# <link class="light-scheme" href="/stylesheets/color_definitions_neutral_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="desktop" data-theme-id="4" href="/stylesheets/desktop_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="discourse-details" data-theme-id="4" href="/stylesheets/discourse-details_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="discourse-local-dates" data-theme-id="4" href="/stylesheets/discourse-local-dates_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="discourse-presence" data-theme-id="4" href="/stylesheets/discourse-presence_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="lazy-yt" data-theme-id="4" href="/stylesheets/lazy-yt_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="poll" data-theme-id="4" href="/stylesheets/poll_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="poll_desktop" data-theme-id="4" href="/stylesheets/poll_desktop_3_a482774e75ca414db0d521f6c7069af2f152ed11.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link data-target="desktop_theme" data-theme-id="4" href="/stylesheets/desktop_theme_4_e3d09e8029537474351b611f9a7b3ecde9baf7da.css?__ws=forum.flowster.app" media="all" rel="stylesheet"/>
# <link href="https://forum.flowster.app/t/virtual-assistant-sending-emails-hubspot/1534.rss" rel="alternate" title="RSS feed of 'Virtual Assistant sending Emails Hubspot'" type="application/rss+xml"/>
# <meta content="eCommerce Sellers Forum" property="og:site_name"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/d9d77a4388bc4cf96f8de8d1a73370da4b34e1e2.png" name="twitter:image"/>
# <meta content="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/d9d77a4388bc4cf96f8de8d1a73370da4b34e1e2.png" property="og:image"/>
# <meta content="https://forum.flowster.app/t/virtual-assistant-sending-emails-hubspot/1534" property="og:url"/>
# <meta content="https://forum.flowster.app/t/virtual-assistant-sending-emails-hubspot/1534" name="twitter:url"/>
# <meta content="Virtual Assistant sending Emails Hubspot" property="og:title"/>
# <meta content="Virtual Assistant sending Emails Hubspot" name="twitter:title"/>
# <meta content="Hello Bright Ideas Tribe,  I would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspot but not being able to view your emails. How would I go about setting this up? Thanks!" property="og:description"/>
# <meta content="Hello Bright Ideas Tribe,  I would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspot but not being able to view your emails. How would I go about setting this up? Thanks!" name="twitter:description"/>
# <meta content="2020-11-18T20:12:44+00:00" property="article:published_time"/>
# <meta content="true" property="og:ignore_canonical"/>
# <meta data-asset-version="80abcd2893ca15b5da77135ffb298636" data-base-uri="" data-base-url="https://forum.flowster.app" data-color-scheme-is-dark="false" data-default-locale="en_US" data-disable-custom-css="false" data-enable-js-error-reporting="true" data-environment="production" data-highlight-js-path="/highlight-js/forum.flowster.app/1d5aed44039a872eadf84f24f60b2b7b0e066bae.js" data-letter-avatar-version="5_70a404e2c8e633b245e797a566d32dc7" data-markdown-it-url="/assets/markdown-it-bundle-eb2d56e694ada56c74f860a116b5262e0e9759c99b3b44fb5eb4c96bdc751216.js" data-s3-base-url="//flowster-discourse.sfo2.digitaloceanspaces.com" data-s3-cdn="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com" data-service-worker-url="service-worker-c8000968830b6f6bd33f1e842dffdd569664119d449f93dc7d428d963a71635d.js" data-svg-sprite-path="/svg-sprite/forum.flowster.app/svg-4-206e5bac4a8d008ee63054785c7e84d11c080a7f.js" data-user-color-scheme-id="3" data-user-dark-scheme-id="-1" id="data-discourse-setup"/>
# <script src="/svg-sprite/forum.flowster.app/svg-4-206e5bac4a8d008ee63054785c7e84d11c080a7f.js"></script><style id="image-sizing-hack">#reply-control .d-editor-preview img:not(.thumbnail):not(.ytp-thumbnail-image), .cooked img:not(.thumbnail):not(.ytp-thumbnail-image) {max-width:690px;max-height:500px;}</style><script src="/javascripts/magnific-popup/1.1.0/jquery.magnific-popup.min.js"></script><script src="/highlight-js/forum.flowster.app/1d5aed44039a872eadf84f24f60b2b7b0e066bae.js"></script></head>
# <body class="archetype-regular category category-product-sourcing docked">
# <section class="ember-application" id="main">
# <div class="ember-view" id="ember4"><!-- -->
# <!-- -->
# <div class="d-header-wrap ember-view" id="ember5"><header class="d-header clearfix"><div class="wrap"><div class="contents clearfix">
# <div class="title"><a data-auto-route="true" href="/"><img alt="eCommerce Sellers Forum" class="logo-small" id="site-logo" src="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/d56ae7ff49589f6aab0d6d72679b2de33f65bdd1.png" width="36"/></a></div>
# <div class="extra-info-wrapper two-rows"><div class="extra-info two-rows"><div class="title-wrapper"><h1 class="header-title"><div class="topic-statuses"></div><a class="widget-link topic-link" data-topic-id="1534" href="/t/virtual-assistant-sending-emails-hubspot/1534" title=""><span>Virtual Assistant sending Emails Hubspot</span></a></h1><div class="categories-wrapper"><a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a></div></div></div></div>
# <div class="panel clearfix"><span class="header-buttons"><button class="widget-button btn btn-primary btn-small login-button btn-icon-text"><svg aria-hidden="true" class="fa d-icon d-icon-user svg-icon svg-node"><use xlink:href="#user"></use></svg><span class="d-button-label">Log In</span></button></span><ul class="icons d-header-icons" role="navigation"><li class="header-dropdown-toggle search-dropdown"><a aria-label="search topics, posts, users, or categories" class="icon btn-flat" data-auto-route="true" href="/search" id="search-button" title="search topics, posts, users, or categories"><svg aria-hidden="true" class="fa d-icon d-icon-search svg-icon svg-node"><use xlink:href="#search"></use></svg></a></li><li class="header-dropdown-toggle hamburger-dropdown"><a aria-label="go to another topic list or category" class="icon btn-flat" data-auto-route="true" href="" id="toggle-hamburger-menu" title="go to another topic list or category"><svg aria-hidden="true" class="fa d-icon d-icon-bars svg-icon svg-node"><use xlink:href="#bars"></use></svg></a></li></ul></div>
# </div></div></header></div>
# <!-- -->
# <div class="wrap" id="main-outlet" role="main">
# <div class="above-main-container-outlet banner-themes ember-view" id="ember7">
# <!-- --> <span class="ember-view" id="ember8"> <div class="custom-banner-outlet banner ember-view" id="ember10">
# <div class="ember-view" id="ember11"><div class="banner-box"><div class="container"><div class="button-container"><button aria-label="Close the banner" class="widget-button btn close btn-icon-text" title="Close the banner"><svg aria-hidden="true" class="fa d-icon d-icon-times svg-icon svg-node"><use xlink:href="#times"></use></svg><span class="d-button-label">Close</span></button></div><div class="section-header"><div style="height:250px;">
# <div class="flowster-banner-bg">
# <h1 class="x-title">
#             Our Community of eCommerce Entrepreneurs
#         </h1>
# <div class="colored-line"></div>
# <div class="description" style="color:white; font-size:1.2em; max-width:600px;">
# <p>
#                 Help each other to discover strategies and develop SOPs to ignite higher levels of growth, profitability, and operational efficiency.
#             </p>
# </div>
# </div>
# </div></div><div id="banner-content_wrap"><div class="row"></div></div></div></div></div>
# </div>
# </span>
# </div>
# <div class="container">
# <div class="ember-view" id="ember12"></div>
# <div class="controls ember-view" id="ember13"><!-- --></div>
# <div class="ember-view" id="ember14"><!-- --></div>
# <div class="ember-view" id="ember15"><!-- --></div>
# <div class="hidden create-topics-notice ember-view" id="ember16"><!-- --></div>
# <!-- -->
# </div>
# <div class="regular category-product-sourcing ember-view" id="ember17"> <div class="ember-view" id="ember18"></div>
# <div class="container">
# <div class="ember-view" id="ember19"><!-- --></div>
# </div>
# <!-- -->
# <span class="ember-view" id="ember20"><!-- --></span>
# <div class="ember-view" id="topic-title"><div class="container">
# <div class="title-wrapper">
# <h1 data-topic-id="1534">
# <div class="ember-view" id="ember21"><!-- --></div>
# <div class="topic-statuses ember-view" id="ember22"><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --><!-- --></div>
# <a class="fancy-title" data-ember-action="" data-ember-action-23="23" href="/t/virtual-assistant-sending-emails-hubspot/1534">
#                 Virtual Assistant sending Emails Hubspot
#               </a>
# <!-- --> </h1>
# <div class="topic-category ember-view" id="ember24"> <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# <div class="topic-header-extra">
# <!-- --> <!-- -->
# </div>
# <span class="ember-view" id="ember25"><!-- --></span>
# </div>
# </div>
# <span class="ember-view" id="ember26"><!-- --></span>
# </div>
# </div>
# <!-- -->
# <div class="container posts">
# <div class="selected-posts hidden">
# <div class="ember-view" id="ember27"><p>
# <span class="ember-view" id="ember28">You have selected <b>0</b> posts.
# </span>
# </p>
# <p>
# <a class="select-all" data-ember-action="" data-ember-action-29="29" href="">
#       select all
#     </a>
# </p>
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <!-- -->
# <p class="cancel">
# <a data-ember-action="" data-ember-action-30="30" href="">
#     cancel selecting
#   </a>
# </p>
# </div>
# </div>
# <div class="topic-navigation ember-view" id="ember31"> <div class="ember-view" id="ember86"><div class="timeline-container timeline-docked timeline-docked-bottom"><div class="topic-timeline"><div class="timeline-controls"></div><div class="timeline-scrollarea-wrapper"><div class="timeline-date-wrapper"><a class="widget-link start-date" href="" title="Nov 18"><span class="d-label">Nov 18</span></a></div><div class="timeline-scrollarea" style="height: 300px"><div class="timeline-padding" style="height: 0px"></div><div class="timeline-scroller" style="height: 50px"><div class="timeline-handle"></div><div class="timeline-scroller-content"><div class="timeline-replies">1 / 6</div><div class="timeline-ago">Nov 19</div></div></div><div class="timeline-padding" style="height: 250px"></div></div><div class="timeline-date-wrapper"><a class="widget-link now-date" href="" title="22d ago"><span class="d-label">22d ago</span></a></div></div><div class="timeline-footer-controls"></div></div></div></div>
# </div>
# <div class="row">
# <section class="topic-area" data-topic-id="1534" id="topic">
# <div class="posts-wrapper">
# <div class="loading-container ember-view" id="ember34">
# </div>
# <span class="ember-view" id="ember35"><!-- --></span>
# <div class="ember-view" id="ember36"><div class="post-stream"><div class="topic-post clearfix topic-owner regular"><article class="boxed onscreen-post" data-post-id="3462" data-topic-id="1534" data-user-id="477" id="post_1"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="grant" href="/u/grant"><img alt="" class="avatar" height="45" src="/letter_avatar_proxy/v4/letter/g/a5b964/45.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="grant" href="/u/grant">grant</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="1" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534" href="/t/virtual-assistant-sending-emails-hubspot/1534"><span class="relative-date" data-format="tiny" data-time="1605730364779" title="Nov 18, 2020 9:12 pm">23d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Hello Bright Ideas Tribe,<br/>
# I would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspot but not being able to view your emails. How would I go about setting this up? Thanks!</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="1" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div><div class="topic-map"><section class="map map-collapsed"><nav class="buttons"><button aria-label="toggle topic details" class="widget-button btn btn no-text btn-icon" title="toggle topic details"><svg aria-hidden="true" class="fa d-icon d-icon-chevron-down svg-icon svg-node"><use xlink:href="#chevron-down"></use></svg></button></nav><ul class="clearfix"><li class="created-at"><h4 role="presentation">created</h4><div class="topic-map-post created-at"><a aria-hidden="true" class="trigger-user-card" data-user-card="grant"><img alt="" class="avatar" height="20" src="/letter_avatar_proxy/v4/letter/g/a5b964/20.png" title="Grant" width="20"/></a><span class="relative-date" data-format="tiny" data-time="1605730364666" title="Nov 18, 2020 9:12 pm">23d</span></div></li><li class="last-reply"><a href="/t/virtual-assistant-sending-emails-hubspot/1534/6"><h4 role="presentation">last reply</h4><div class="topic-map-post last-reply"><a aria-hidden="true" class="trigger-user-card" data-user-card="Mitch"><img alt="" class="avatar" height="20" src="/user_avatar/forum.flowster.app/mitch/20/35_2.png" title="Mitch" width="20"/></a><span class="relative-date" data-format="tiny" data-time="1605822460461" title="Nov 19, 2020 10:47 pm">22d</span></div></a></li><li class="replies"><span class="number">5</span><h4 role="presentation">replies</h4></li><li class="secondary views"><span class="number">78</span><h4 role="presentation">views</h4></li><li class="secondary users"><span class="number">2</span><h4 role="presentation">users</h4></li><li class="secondary links"><span class="number">1</span><h4 role="presentation">link</h4></li><li class="avatars"><div><a class="poster trigger-user-card" data-user-card="Mitch" title="Mitch"><img alt="" class="avatar" height="32" src="/user_avatar/forum.flowster.app/mitch/32/35_2.png" title="Mitch" width="32"/><span class="post-count">3</span></a></div><div><a class="poster trigger-user-card" data-user-card="grant" title="grant"><img alt="" class="avatar" height="32" src="/letter_avatar_proxy/v4/letter/g/a5b964/32.png" title="Grant" width="32"/><span class="post-count">3</span></a></div></li></ul></section></div></div></div></article></div><div class="topic-post clearfix regular"><article class="boxed onscreen-post" data-post-id="3463" data-topic-id="1534" data-user-id="9" id="post_2"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="Mitch" href="/u/Mitch"><img alt="" class="avatar" height="45" src="/user_avatar/forum.flowster.app/mitch/45/35_2.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="Mitch" href="/u/Mitch">Mitch</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="2" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/2" href="/t/virtual-assistant-sending-emails-hubspot/1534/2"><span class="relative-date" data-format="tiny" data-time="1605794866357" title="Nov 19, 2020 3:07 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><aside class="onebox allowlistedgeneric">
# <header class="source">
# <img class="site-icon d-lazyload" height="150" src="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/3bdeb201b5096eaca6e0baf7ed190b9a2b00baa0.png" width="150"/>
# <a href="https://knowledge.hubspot.com/email/create-and-send-marketing-emails" rel="noopener nofollow ugc" target="_blank">knowledge.hubspot.com <span class="badge badge-notification clicks" title="1 click">1</span></a>
# </header>
# <article class="onebox-body">
# <div class="aspect-image" style="--aspect-ratio:667/226;"><img class="thumbnail d-lazyload" height="226" src="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/5d977584e1404cfd0b31a2f1a1fd85d227d27e41.jpeg" width="667"/></div>
# <h3><a href="https://knowledge.hubspot.com/email/create-and-send-marketing-emails" rel="noopener nofollow ugc" target="_blank">Create and send marketing emails in the classic email editor <span class="badge badge-notification clicks" title="1 click">1</span></a></h3>
# <p>Learn how to use the email tool to create and send marketing emails or save marketing emails for automation.</p>
# </article>
# <div class="onebox-metadata">
# </div>
# <div style="clear: both"></div>
# </aside>
# <p>You can use HubSpot but there are also plenty of other tools you can have your VA set up campaigns in and send emails without having to give them access to your inbox.</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="2" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/2" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div><div class="topic-post clearfix topic-owner regular"><article class="boxed onscreen-post" data-post-id="3464" data-topic-id="1534" data-user-id="477" id="post_3"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="grant" href="/u/grant"><img alt="" class="avatar" height="45" src="/letter_avatar_proxy/v4/letter/g/a5b964/45.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="grant" href="/u/grant">grant</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="3" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/3" href="/t/virtual-assistant-sending-emails-hubspot/1534/3"><span class="relative-date" data-format="tiny" data-time="1605810234144" title="Nov 19, 2020 7:23 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Hi Mitch, thanks for the information and post. What other tools would you recommend that would allow my VA to set up email campaigns to prospective suppliers and send emails without being able to access my inbox?</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="3" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/3" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div><div class="topic-post clearfix regular"><article class="boxed onscreen-post" data-post-id="3465" data-topic-id="1534" data-user-id="9" id="post_4"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="Mitch" href="/u/Mitch"><img alt="" class="avatar" height="45" src="/user_avatar/forum.flowster.app/mitch/45/35_2.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="Mitch" href="/u/Mitch">Mitch</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="4" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/4" href="/t/virtual-assistant-sending-emails-hubspot/1534/4"><span class="relative-date" data-format="tiny" data-time="1605810587536" title="Nov 19, 2020 7:29 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p><a class="mention" href="/u/grant">@grant</a> along with Hubspot, I’d recommend:</p>
# <ul>
# <li>
# <p>Woodpecker</p>
# </li>
# <li>
# <p>Lemlist</p>
# </li>
# <li>
# <p>Mailchimp</p>
# </li>
# <li>
# <p>Apollo</p>
# </li>
# </ul>
# <p>Woodpecker is a pretty good entry level email sending service.  I haven’t used HubSpot’s email marketing tools but they are probably free to you if you are using it for a CRM.  You might want to start with that but there are some good other tools you could use also.</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="4" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/4" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div><div class="topic-post clearfix topic-owner regular"><article class="boxed onscreen-post" data-post-id="3466" data-topic-id="1534" data-user-id="477" id="post_5"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="grant" href="/u/grant"><img alt="" class="avatar" height="45" src="/letter_avatar_proxy/v4/letter/g/a5b964/45.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="grant" href="/u/grant">grant</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="5" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/5" href="/t/virtual-assistant-sending-emails-hubspot/1534/5"><span class="relative-date" data-format="tiny" data-time="1605812400670" title="Nov 19, 2020 8:00 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Hi <a class="mention" href="/u/mitch">@Mitch</a> ,<br/>
# Thanks for the suggestions and recommendations on the different tools. I think I will probably start with Hubspot as you mentioned. Thanks for all of the intel Mitch!</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="5" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/5" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div><div class="topic-post clearfix regular"><article class="boxed onscreen-post" data-post-id="3467" data-topic-id="1534" data-user-id="9" id="post_6"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="Mitch" href="/u/Mitch"><img alt="" class="avatar" height="45" src="/user_avatar/forum.flowster.app/mitch/45/35_2.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="Mitch" href="/u/Mitch">Mitch</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="6" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/6" href="/t/virtual-assistant-sending-emails-hubspot/1534/6"><span class="relative-date" data-format="tiny" data-time="1605822460461" title="Nov 19, 2020 10:47 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Anytime!</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="6" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/6" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div></div></div>
# <div class="loading-container ember-view" id="ember37">
# </div>
# </div>
# <div id="topic-bottom"></div>
# <div class="loading-container ember-view" id="ember38">
# <!-- -->
# <!-- -->
# <div class="ember-view" id="ember39"><!-- --></div>
# <div class="topic-status-info ember-view" id="ember40"><!-- --></div>
# <!-- -->
# </div>
# </section>
# </div>
# </div>
# <div id="topic-footer-buttons">
# <button aria-label="Reply" class="btn-primary pull-right btn btn-icon-text ember-view" id="ember41" type="button"><svg class="fa d-icon d-icon-reply svg-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#reply"></use></svg><span class="d-button-label">Reply<!-- --></span>
# </button>
# </div>
# <span class="ember-view" id="ember42"><!-- --></span>
# <div class="suggested-topics-wrapper">
# <!-- --> <div aria-labelledby="suggested-topics-title" class="suggested-topics" id="suggested-topics" role="complementary">
# <h3 class="suggested-topics-title" id="suggested-topics-title">
#     Suggested Topics
#   </h3>
# <div class="topics">
# <div class="ember-view" id="ember44"><div class="loading-container ember-view" id="ember45"> <!-- -->
# <table class="topic-list ember-view" id="ember46"> <thead>
# <tr><th class="default" data-sort-order="default">Topic</th>
# <th class="posts num" data-sort-order="posts">Replies</th>
# <th class="views num" data-sort-order="views">Views</th>
# <th class="activity num" data-sort-order="activity">Activity</th>
# </tr>
# </thead>
# <!-- -->
# <tbody>
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1507" id="ember49">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1507" href="/t/virtual-assistant-using-email/1507">Virtual Assistant Using Email</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 4 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 4 replies" class="number">4</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 126 times">126</span></td>
# <td class="num age activity" title="First post: Oct 12, 2020 1:59 am
# Posted: Oct 13, 2020 7:26 pm">
# <a class="post-activity" href="/t/virtual-assistant-using-email/1507/5"><span class="relative-date" data-format="tiny" data-time="1602613590972">Oct 13</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1243" id="ember51">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1243" href="/t/price-checker-sales-estimate/1243">Price Checker Sales Estimate</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 1 reply">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 1 reply" class="number">1</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 204 times">204</span></td>
# <td class="num age activity" title="First post: Feb 7, 2020 3:46 pm
# Posted: Feb 7, 2020 3:58 pm">
# <a class="post-activity" href="/t/price-checker-sales-estimate/1243/2"><span class="relative-date" data-format="tiny" data-time="1581087490359">Feb 7</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1468" id="ember53">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1468" href="/t/how-to-get-a-reseller-permit-in-usa-as-a-canadian/1468">How to get a Reseller Permit in USA as a Canadian?</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 3 replies" class="number">3</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 188 times">188</span></td>
# <td class="num age activity" title="First post: Aug 26, 2020 12:03 am
# Posted: Aug 27, 2020 1:49 pm">
# <a class="post-activity" href="/t/how-to-get-a-reseller-permit-in-usa-as-a-canadian/1468/4"><span class="relative-date" data-format="tiny" data-time="1598532586214">Aug 27</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-product-sourcing ember-view" data-topic-id="1274" id="ember55">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1274" href="/t/virtual-assistants/1274">Virtual Assistants</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a>
# </div>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 3 replies">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 3 replies" class="number">3</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 302 times">302</span></td>
# <td class="num age activity" title="First post: Feb 20, 2020 12:06 am
# Posted: Feb 26, 2020 1:01 am">
# <a class="post-activity" href="/t/virtual-assistants/1274/4"><span class="relative-date" data-format="tiny" data-time="1582675264916">Feb 26</span></a>
# </td>
# </tr>
# <!-- -->
# <tr class="topic-list-item category-amazon-specific-amazon-inventory-management ember-view" data-topic-id="1236" id="ember57">
# <td class="main-link clearfix" colspan="1">
# <span class="link-top-line"><a class="title raw-link raw-topic-link" data-topic-id="1236" href="/t/seller-legend-compare-month-over-month-data/1236">Seller Legend: compare month-over-month data</a><span class="topic-post-badges"></span>
# </span>
# <div class="link-bottom-line">
# <a class="badge-wrapper bullet" href="/c/amazon-specific/amazon-inventory-management/22"><span class="badge-category-parent-bg" style="background-color: #F7941D;"></span><span class="badge-category-bg" style="background-color: #F7941D;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Learn more about inventory management."><span class="category-name">Inventory Management</span></span></a>
# </div>
# </td>
# <td class="num posts-map posts heatmap-" title="This topic has 1 reply">
# <a class="posts-map badge-posts heatmap-" href="">
# <span aria-label="This topic has 1 reply" class="number">1</span>
# </a>
# </td>
# <td class="num views"><span class="number" title="this topic has been viewed 220 times">220</span></td>
# <td class="num age activity" title="First post: Feb 4, 2020 7:02 pm
# Posted: Feb 4, 2020 10:41 pm">
# <a class="post-activity" href="/t/seller-legend-compare-month-over-month-data/1236/2"><span class="relative-date" data-format="tiny" data-time="1580852496533">Feb 4</span></a>
# </td>
# </tr>
# <!-- -->
# </tbody>
# </table>
# </div></div>
# </div>
# <h3 class="suggested-topics-message">
#     Want to read more? Browse other topics in <a class="badge-wrapper bullet" href="/c/product-sourcing/8"><span class="badge-category-bg" style="background-color: #3AB54A;"></span><span class="badge-category clear-badge" data-drop-close="true" title="Have questions about sourcing products? This is the category to use. Please be sure to select the most appropriate sub-category for your questions."><span class="category-name">Product Sourcing</span></span></a> or <a href="/latest">view latest topics</a>.
#   </h3>
# </div>
# </div>
# <div class="ember-view" id="share-link"><div class="title">
# <h3>[en_US.share.topic]</h3>
# <!-- --></div>
# <div>
# <input aria-label="Copy and share URL" type="text"/>
# </div>
# <div class="actions">
# <div class="sources">
# <div class="social-link ember-view" id="ember59"><a aria-label="Share on Twitter" data-ember-action="" data-ember-action-60="60" href="" title="Share on Twitter">
# <svg class="fa d-icon d-icon-fab-twitter-square svg-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#fab-twitter-square"></use></svg>
# </a>
# </div>
# <div class="social-link ember-view" id="ember62"><a aria-label="Share on Facebook" data-ember-action="" data-ember-action-63="63" href="" title="Share on Facebook">
# <svg class="fa d-icon d-icon-fab-facebook svg-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#fab-facebook"></use></svg>
# </a>
# </div>
# <div class="social-link ember-view" id="ember65"><a aria-label="Send via email" data-ember-action="" data-ember-action-66="66" href="" title="Send via email">
# <svg class="fa d-icon d-icon-envelope-square svg-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#envelope-square"></use></svg>
# </a>
# </div>
# </div>
# <div class="alt-actions">
# <!-- -->
# <button class="btn btn-flat close btn no-text btn-icon ember-view" id="ember67" title="close" type="button"><svg class="fa d-icon d-icon-times svg-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#times"></use></svg><!-- -->
# </button>
# </div>
# </div>
# </div>
# <div class="quote-button ember-view" id="ember68"><!-- -->
# <span class="quote-sharing">
# <button aria-label="Share" class="btn-flat quote-share-label btn btn-icon-text ember-view" id="ember69" type="button"><svg class="fa d-icon d-icon-share svg-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="#share"></use></svg><span class="d-button-label">Share<!-- --></span>
# </button>
# <span class="quote-share-buttons">
# <button class="btn-flat btn no-text btn-icon ember-view" id="ember70" title="Share on Twitter" type="button"><svg class="fa d-icon d-icon-fab-twitter-square svg-icon svg-string" xmlns="http://www.w3.org/2000/svg"><use xlink:href="
# </symbol><symbol id="discourse-bell-one" viewbox="0 0 448 512">
# <path d="M224 512c35.3 0 64-28.7 64-64H160c0 35.3 28.7 64 64 64zM439.4 362.3c-19.3-20.8-55.5-52-55.5-154.3 0-77.7-54.5-139.9-127.9-155.2V32c0-17.7-14.3-32-32-32s-32 14.3-32 32v20.8C118.6 68.1 64.1 130.3 64.1 208c0 102.3-36.2 133.5-55.5 154.3-6 6.4-8.6 14.1-8.6 21.7.1 16.4 13 32 32.1 32h383.8c19.1 0 32-15.6 32.1-32 .1-7.6-2.6-15.3-8.6-21.7zm-145.2-28c0 8.6-7 15.5-15.5 15.5h-97c-8.6 0-15.5-7-15.5-15.5v-15.8c0-8.6 7-15.5 15.5-15.5h27.1V192.5l-5.1 3.1c-6 6.1-15.9 6.2-22 .1l-11.2-11.1c-6.1-6-6.2-15.9-.1-22l31.6-31.9c3.2-3.2 7.4-4.7 11.5-4.6h26.6c8.6 0 11.5 7 11.5 15.5v161.3h27.1c8.6 0 15.5 7 15.5 15.5v15.9z"></path>
# </symbol><symbol id="discourse-bell-slash" viewbox="0 0 448 512">
# <path d="M442.7 396.2L36.5 70.7c-6.9-5.5-17-4.4-22.5 2.5L4 85.6c-5.5 6.9-4.4 17 2.5 22.5l406.2 325.5c6.9 5.5 17 4.4 22.5-2.5l10-12.5c5.5-6.9 3.7-17.7-3.2-23.2l.7.8zM67.5 368c16.7-22 34.5-55.8 41.4-110.6l-45.5-35.6C60.2 312.6 27 342.5 8.6 362.3 2.6 368.7 0 376.4 0 384c.1 16.4 13 32 32.1 32h279.7l-61.4-48H67.5zM224 96c61.9 0 112 50.1 112 112 0 .2-.1.4-.1.6 0 16.8 1.2 31.8 2.8 45.7l59.5 46.5c-8.3-22.1-14.3-51.5-14.3-92.9 0-77.7-54.5-139.9-127.9-155.2V32c0-17.7-14.3-32-32-32s-32 14.3-32 32v20.8c-26 5.4-49.4 16.9-69.1 32.7l38.2 29.8C179 103.2 200.6 96 224 96zm0 416c35.3 0 64-28.6 64-64H160c0 35.4 28.7 64 64 64z"></path>
# </symbol></svg></div></div></body></html>

# %%
topic_title = ps_soup.find('a', class_='fancy-title').text.strip()

# %%
topic_title
# Out:
# 'Virtual Assistant sending Emails Hubspot'

# %%
topic_category = ps_soup.find('span', class_='category-name').text.strip()

# %%
topic_category
# Out:
# 'Product Sourcing'

# %%
topic_leading_comment = browser.find_element_by_css_selector('.regular > .cooked > p')

# %%
print(topic_leading_comment.text)
# Out:
# Hello Bright Ideas Tribe,
# I would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspot but not being able to view your emails. How would I go about setting this up? Thanks!

# %%
topic_leading_comment = browser.find_element_by_id('post_1')

# %%
print(topic_leading_comment.text)
# Out:
# grant
# 23d
# Hello Bright Ideas Tribe,
# I would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspot but not being able to view your emails. How would I go about setting this up? Thanks!
# created
# 23d
# last reply
# 22d
# 5
# replies
# 78
# views
# 2
# users
# 1
# link
# 3
# 3

# %%
postStream = ps_soup.find('div', class_='post-stream')

# %%
postStream
# Out:
# <div class="post-stream"><div class="topic-post clearfix topic-owner regular"><article class="boxed onscreen-post" data-post-id="3462" data-topic-id="1534" data-user-id="477" id="post_1"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="grant" href="/u/grant"><img alt="" class="avatar" height="45" src="/letter_avatar_proxy/v4/letter/g/a5b964/45.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="grant" href="/u/grant">grant</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="1" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534" href="/t/virtual-assistant-sending-emails-hubspot/1534"><span class="relative-date" data-format="tiny" data-time="1605730364779" title="Nov 18, 2020 9:12 pm">23d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Hello Bright Ideas Tribe,<br/>
# I would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspot but not being able to view your emails. How would I go about setting this up? Thanks!</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="1" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div><div class="topic-map"><section class="map map-collapsed"><nav class="buttons"><button aria-label="toggle topic details" class="widget-button btn btn no-text btn-icon" title="toggle topic details"><svg aria-hidden="true" class="fa d-icon d-icon-chevron-down svg-icon svg-node"><use xlink:href="#chevron-down"></use></svg></button></nav><ul class="clearfix"><li class="created-at"><h4 role="presentation">created</h4><div class="topic-map-post created-at"><a aria-hidden="true" class="trigger-user-card" data-user-card="grant"><img alt="" class="avatar" height="20" src="/letter_avatar_proxy/v4/letter/g/a5b964/20.png" title="Grant" width="20"/></a><span class="relative-date" data-format="tiny" data-time="1605730364666" title="Nov 18, 2020 9:12 pm">23d</span></div></li><li class="last-reply"><a href="/t/virtual-assistant-sending-emails-hubspot/1534/6"><h4 role="presentation">last reply</h4><div class="topic-map-post last-reply"><a aria-hidden="true" class="trigger-user-card" data-user-card="Mitch"><img alt="" class="avatar" height="20" src="/user_avatar/forum.flowster.app/mitch/20/35_2.png" title="Mitch" width="20"/></a><span class="relative-date" data-format="tiny" data-time="1605822460461" title="Nov 19, 2020 10:47 pm">22d</span></div></a></li><li class="replies"><span class="number">5</span><h4 role="presentation">replies</h4></li><li class="secondary views"><span class="number">78</span><h4 role="presentation">views</h4></li><li class="secondary users"><span class="number">2</span><h4 role="presentation">users</h4></li><li class="secondary links"><span class="number">1</span><h4 role="presentation">link</h4></li><li class="avatars"><div><a class="poster trigger-user-card" data-user-card="Mitch" title="Mitch"><img alt="" class="avatar" height="32" src="/user_avatar/forum.flowster.app/mitch/32/35_2.png" title="Mitch" width="32"/><span class="post-count">3</span></a></div><div><a class="poster trigger-user-card" data-user-card="grant" title="grant"><img alt="" class="avatar" height="32" src="/letter_avatar_proxy/v4/letter/g/a5b964/32.png" title="Grant" width="32"/><span class="post-count">3</span></a></div></li></ul></section></div></div></div></article></div><div class="topic-post clearfix regular"><article class="boxed onscreen-post" data-post-id="3463" data-topic-id="1534" data-user-id="9" id="post_2"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="Mitch" href="/u/Mitch"><img alt="" class="avatar" height="45" src="/user_avatar/forum.flowster.app/mitch/45/35_2.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="Mitch" href="/u/Mitch">Mitch</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="2" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/2" href="/t/virtual-assistant-sending-emails-hubspot/1534/2"><span class="relative-date" data-format="tiny" data-time="1605794866357" title="Nov 19, 2020 3:07 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><aside class="onebox allowlistedgeneric">
# <header class="source">
# <img class="site-icon d-lazyload" height="150" src="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/3bdeb201b5096eaca6e0baf7ed190b9a2b00baa0.png" width="150"/>
# <a href="https://knowledge.hubspot.com/email/create-and-send-marketing-emails" rel="noopener nofollow ugc" target="_blank">knowledge.hubspot.com <span class="badge badge-notification clicks" title="1 click">1</span></a>
# </header>
# <article class="onebox-body">
# <div class="aspect-image" style="--aspect-ratio:667/226;"><img class="thumbnail d-lazyload" height="226" src="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/5d977584e1404cfd0b31a2f1a1fd85d227d27e41.jpeg" width="667"/></div>
# <h3><a href="https://knowledge.hubspot.com/email/create-and-send-marketing-emails" rel="noopener nofollow ugc" target="_blank">Create and send marketing emails in the classic email editor <span class="badge badge-notification clicks" title="1 click">1</span></a></h3>
# <p>Learn how to use the email tool to create and send marketing emails or save marketing emails for automation.</p>
# </article>
# <div class="onebox-metadata">
# </div>
# <div style="clear: both"></div>
# </aside>
# <p>You can use HubSpot but there are also plenty of other tools you can have your VA set up campaigns in and send emails without having to give them access to your inbox.</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="2" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/2" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div><div class="topic-post clearfix topic-owner regular"><article class="boxed onscreen-post" data-post-id="3464" data-topic-id="1534" data-user-id="477" id="post_3"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="grant" href="/u/grant"><img alt="" class="avatar" height="45" src="/letter_avatar_proxy/v4/letter/g/a5b964/45.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="grant" href="/u/grant">grant</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="3" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/3" href="/t/virtual-assistant-sending-emails-hubspot/1534/3"><span class="relative-date" data-format="tiny" data-time="1605810234144" title="Nov 19, 2020 7:23 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Hi Mitch, thanks for the information and post. What other tools would you recommend that would allow my VA to set up email campaigns to prospective suppliers and send emails without being able to access my inbox?</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="3" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/3" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div><div class="topic-post clearfix regular"><article class="boxed onscreen-post" data-post-id="3465" data-topic-id="1534" data-user-id="9" id="post_4"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="Mitch" href="/u/Mitch"><img alt="" class="avatar" height="45" src="/user_avatar/forum.flowster.app/mitch/45/35_2.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="Mitch" href="/u/Mitch">Mitch</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="4" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/4" href="/t/virtual-assistant-sending-emails-hubspot/1534/4"><span class="relative-date" data-format="tiny" data-time="1605810587536" title="Nov 19, 2020 7:29 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p><a class="mention" href="/u/grant">@grant</a> along with Hubspot, I’d recommend:</p>
# <ul>
# <li>
# <p>Woodpecker</p>
# </li>
# <li>
# <p>Lemlist</p>
# </li>
# <li>
# <p>Mailchimp</p>
# </li>
# <li>
# <p>Apollo</p>
# </li>
# </ul>
# <p>Woodpecker is a pretty good entry level email sending service.  I haven’t used HubSpot’s email marketing tools but they are probably free to you if you are using it for a CRM.  You might want to start with that but there are some good other tools you could use also.</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="4" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/4" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div><div class="topic-post clearfix topic-owner regular"><article class="boxed onscreen-post" data-post-id="3466" data-topic-id="1534" data-user-id="477" id="post_5"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="grant" href="/u/grant"><img alt="" class="avatar" height="45" src="/letter_avatar_proxy/v4/letter/g/a5b964/45.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="grant" href="/u/grant">grant</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="5" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/5" href="/t/virtual-assistant-sending-emails-hubspot/1534/5"><span class="relative-date" data-format="tiny" data-time="1605812400670" title="Nov 19, 2020 8:00 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Hi <a class="mention" href="/u/mitch">@Mitch</a> ,<br/>
# Thanks for the suggestions and recommendations on the different tools. I think I will probably start with Hubspot as you mentioned. Thanks for all of the intel Mitch!</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="5" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/5" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div><div class="topic-post clearfix regular"><article class="boxed onscreen-post" data-post-id="3467" data-topic-id="1534" data-user-id="9" id="post_6"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="Mitch" href="/u/Mitch"><img alt="" class="avatar" height="45" src="/user_avatar/forum.flowster.app/mitch/45/35_2.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="Mitch" href="/u/Mitch">Mitch</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="6" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/6" href="/t/virtual-assistant-sending-emails-hubspot/1534/6"><span class="relative-date" data-format="tiny" data-time="1605822460461" title="Nov 19, 2020 10:47 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Anytime!</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="6" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/6" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div></div>

# %%
# ?postStream.find

# %%
postsDivs = postStream.find_all('div', {'class': ['topic-post clearfix topic-owner regular', 'topic-post clearfix regular']})

# %%
print(postsDivs)
# Out:
# [<div class="topic-post clearfix topic-owner regular"><article class="boxed onscreen-post" data-post-id="3462" data-topic-id="1534" data-user-id="477" id="post_1"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="grant" href="/u/grant"><img alt="" class="avatar" height="45" src="/letter_avatar_proxy/v4/letter/g/a5b964/45.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="grant" href="/u/grant">grant</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="1" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534" href="/t/virtual-assistant-sending-emails-hubspot/1534"><span class="relative-date" data-format="tiny" data-time="1605730364779" title="Nov 18, 2020 9:12 pm">23d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Hello Bright Ideas Tribe,<br/>
# I would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspot but not being able to view your emails. How would I go about setting this up? Thanks!</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="1" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div><div class="topic-map"><section class="map map-collapsed"><nav class="buttons"><button aria-label="toggle topic details" class="widget-button btn btn no-text btn-icon" title="toggle topic details"><svg aria-hidden="true" class="fa d-icon d-icon-chevron-down svg-icon svg-node"><use xlink:href="#chevron-down"></use></svg></button></nav><ul class="clearfix"><li class="created-at"><h4 role="presentation">created</h4><div class="topic-map-post created-at"><a aria-hidden="true" class="trigger-user-card" data-user-card="grant"><img alt="" class="avatar" height="20" src="/letter_avatar_proxy/v4/letter/g/a5b964/20.png" title="Grant" width="20"/></a><span class="relative-date" data-format="tiny" data-time="1605730364666" title="Nov 18, 2020 9:12 pm">23d</span></div></li><li class="last-reply"><a href="/t/virtual-assistant-sending-emails-hubspot/1534/6"><h4 role="presentation">last reply</h4><div class="topic-map-post last-reply"><a aria-hidden="true" class="trigger-user-card" data-user-card="Mitch"><img alt="" class="avatar" height="20" src="/user_avatar/forum.flowster.app/mitch/20/35_2.png" title="Mitch" width="20"/></a><span class="relative-date" data-format="tiny" data-time="1605822460461" title="Nov 19, 2020 10:47 pm">22d</span></div></a></li><li class="replies"><span class="number">5</span><h4 role="presentation">replies</h4></li><li class="secondary views"><span class="number">78</span><h4 role="presentation">views</h4></li><li class="secondary users"><span class="number">2</span><h4 role="presentation">users</h4></li><li class="secondary links"><span class="number">1</span><h4 role="presentation">link</h4></li><li class="avatars"><div><a class="poster trigger-user-card" data-user-card="Mitch" title="Mitch"><img alt="" class="avatar" height="32" src="/user_avatar/forum.flowster.app/mitch/32/35_2.png" title="Mitch" width="32"/><span class="post-count">3</span></a></div><div><a class="poster trigger-user-card" data-user-card="grant" title="grant"><img alt="" class="avatar" height="32" src="/letter_avatar_proxy/v4/letter/g/a5b964/32.png" title="Grant" width="32"/><span class="post-count">3</span></a></div></li></ul></section></div></div></div></article></div>, <div class="topic-post clearfix regular"><article class="boxed onscreen-post" data-post-id="3463" data-topic-id="1534" data-user-id="9" id="post_2"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="Mitch" href="/u/Mitch"><img alt="" class="avatar" height="45" src="/user_avatar/forum.flowster.app/mitch/45/35_2.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="Mitch" href="/u/Mitch">Mitch</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="2" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/2" href="/t/virtual-assistant-sending-emails-hubspot/1534/2"><span class="relative-date" data-format="tiny" data-time="1605794866357" title="Nov 19, 2020 3:07 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><aside class="onebox allowlistedgeneric">
# <header class="source">
# <img class="site-icon d-lazyload" height="150" src="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/3bdeb201b5096eaca6e0baf7ed190b9a2b00baa0.png" width="150"/>
# <a href="https://knowledge.hubspot.com/email/create-and-send-marketing-emails" rel="noopener nofollow ugc" target="_blank">knowledge.hubspot.com <span class="badge badge-notification clicks" title="1 click">1</span></a>
# </header>
# <article class="onebox-body">
# <div class="aspect-image" style="--aspect-ratio:667/226;"><img class="thumbnail d-lazyload" height="226" src="https://flowster-discourse.sfo2.cdn.digitaloceanspaces.com/original/1X/5d977584e1404cfd0b31a2f1a1fd85d227d27e41.jpeg" width="667"/></div>
# <h3><a href="https://knowledge.hubspot.com/email/create-and-send-marketing-emails" rel="noopener nofollow ugc" target="_blank">Create and send marketing emails in the classic email editor <span class="badge badge-notification clicks" title="1 click">1</span></a></h3>
# <p>Learn how to use the email tool to create and send marketing emails or save marketing emails for automation.</p>
# </article>
# <div class="onebox-metadata">
# </div>
# <div style="clear: both"></div>
# </aside>
# <p>You can use HubSpot but there are also plenty of other tools you can have your VA set up campaigns in and send emails without having to give them access to your inbox.</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="2" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/2" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div>, <div class="topic-post clearfix topic-owner regular"><article class="boxed onscreen-post" data-post-id="3464" data-topic-id="1534" data-user-id="477" id="post_3"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="grant" href="/u/grant"><img alt="" class="avatar" height="45" src="/letter_avatar_proxy/v4/letter/g/a5b964/45.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="grant" href="/u/grant">grant</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="3" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/3" href="/t/virtual-assistant-sending-emails-hubspot/1534/3"><span class="relative-date" data-format="tiny" data-time="1605810234144" title="Nov 19, 2020 7:23 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Hi Mitch, thanks for the information and post. What other tools would you recommend that would allow my VA to set up email campaigns to prospective suppliers and send emails without being able to access my inbox?</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="3" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/3" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div>, <div class="topic-post clearfix regular"><article class="boxed onscreen-post" data-post-id="3465" data-topic-id="1534" data-user-id="9" id="post_4"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="Mitch" href="/u/Mitch"><img alt="" class="avatar" height="45" src="/user_avatar/forum.flowster.app/mitch/45/35_2.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="Mitch" href="/u/Mitch">Mitch</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="4" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/4" href="/t/virtual-assistant-sending-emails-hubspot/1534/4"><span class="relative-date" data-format="tiny" data-time="1605810587536" title="Nov 19, 2020 7:29 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p><a class="mention" href="/u/grant">@grant</a> along with Hubspot, I’d recommend:</p>
# <ul>
# <li>
# <p>Woodpecker</p>
# </li>
# <li>
# <p>Lemlist</p>
# </li>
# <li>
# <p>Mailchimp</p>
# </li>
# <li>
# <p>Apollo</p>
# </li>
# </ul>
# <p>Woodpecker is a pretty good entry level email sending service.  I haven’t used HubSpot’s email marketing tools but they are probably free to you if you are using it for a CRM.  You might want to start with that but there are some good other tools you could use also.</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="4" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/4" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div>, <div class="topic-post clearfix topic-owner regular"><article class="boxed onscreen-post" data-post-id="3466" data-topic-id="1534" data-user-id="477" id="post_5"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="grant" href="/u/grant"><img alt="" class="avatar" height="45" src="/letter_avatar_proxy/v4/letter/g/a5b964/45.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="grant" href="/u/grant">grant</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="5" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/5" href="/t/virtual-assistant-sending-emails-hubspot/1534/5"><span class="relative-date" data-format="tiny" data-time="1605812400670" title="Nov 19, 2020 8:00 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Hi <a class="mention" href="/u/mitch">@Mitch</a> ,<br/>
# Thanks for the suggestions and recommendations on the different tools. I think I will probably start with Hubspot as you mentioned. Thanks for all of the intel Mitch!</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="5" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/5" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div>, <div class="topic-post clearfix regular"><article class="boxed onscreen-post" data-post-id="3467" data-topic-id="1534" data-user-id="9" id="post_6"><a aria-hidden="true" class="tabLoc" href="" tabindex="-1"></a><div class="row"><div class="topic-avatar"><a aria-hidden="true" class="trigger-user-card main-avatar" data-user-card="Mitch" href="/u/Mitch"><img alt="" class="avatar" height="45" src="/user_avatar/forum.flowster.app/mitch/45/35_2.png" width="45"/></a><div class="poster-avatar-extra"></div></div><div class="topic-body clearfix"><div class="topic-meta-data"><div class="names trigger-user-card"><span class="first username"><a data-user-card="Mitch" href="/u/Mitch">Mitch</a></span></div><div class="post-infos"><div class="post-info post-date"><a class="post-date" data-post-number="6" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/6" href="/t/virtual-assistant-sending-emails-hubspot/1534/6"><span class="relative-date" data-format="tiny" data-time="1605822460461" title="Nov 19, 2020 10:47 pm">22d</span></a></div><div class="read-state read" title="Post is unread"><svg aria-hidden="true" class="fa d-icon d-icon-circle svg-icon svg-node"><use xlink:href="#circle"></use></svg></div></div></div><div class="regular contents"><div class="cooked"><p>Anytime!</p></div><section class="post-menu-area clearfix"><nav class="post-controls clearfix expanded"><div class="actions"><div class="double-button"><button aria-label="like this post" class="widget-button btn-flat toggle-like like no-text btn-icon" title="like this post"><svg aria-hidden="true" class="fa d-icon d-icon-d-unliked svg-icon svg-node"><use xlink:href="#far-heart"></use></svg></button></div><button aria-label="share a link to this post" class="widget-button btn-flat share no-text btn-icon" data-post-number="6" data-share-url="/t/virtual-assistant-sending-emails-hubspot/1534/6" title="share a link to this post"><svg aria-hidden="true" class="fa d-icon d-icon-link svg-icon svg-node"><use xlink:href="#link"></use></svg></button></div></nav></section></div><section class="post-actions">
# </section><div class="post-links-container"></div></div></div></article></div>]

# %%
len(postsDivs)
# Out:
# 6

# %%
postsDivs[0].find('div', class_='cooked').text
# Out:
# 'Hello Bright Ideas Tribe,\nI would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspot but not being able to view your emails. How would I go about setting this up? Thanks!'

# %%
comments = []
for i in range(len(postsDivs)):
    comment = postsDivs[i].find('div', class_='cooked').text
    #postsDivs[i].find('div', class_='cooked').text.replace('\n', ' ')
    comments.append(comment)

leading_comment = comments[0]
if len(comments) == 1:
    other_comments = []
else:
    other_comments = comments[1:]

# %%
leading_comment
# Out:
# 'Hello Bright Ideas Tribe,\nI would like to give my VA access to sending emails for me but not be able to see my inbox and read and view the replies. I have heard some of you mention having a VA send emails through Hubspot but not being able to view your emails. How would I go about setting this up? Thanks!'

# %%
other_comments
# Out:
# ['\n\n\nknowledge.hubspot.com 1\n\n\n\nCreate and send marketing emails in the classic email editor 1\nLearn how to use the email tool to create and send marketing emails or save marketing emails for automation.\n\n\n\n\n\nYou can use HubSpot but there are also plenty of other tools you can have your VA set up campaigns in and send emails without having to give them access to your inbox.',
#  'Hi Mitch, thanks for the information and post. What other tools would you recommend that would allow my VA to set up email campaigns to prospective suppliers and send emails without being able to access my inbox?',
#  '@grant along with Hubspot, I’d recommend:\n\n\nWoodpecker\n\n\nLemlist\n\n\nMailchimp\n\n\nApollo\n\n\nWoodpecker is a pretty good entry level email sending service.  I haven’t used HubSpot’s email marketing tools but they are probably free to you if you are using it for a CRM.  You might want to start with that but there are some good other tools you could use also.',
#  'Hi @Mitch ,\nThanks for the suggestions and recommendations on the different tools. I think I will probably start with Hubspot as you mentioned. Thanks for all of the intel Mitch!',
#  'Anytime!']

# %%
created = postStream.find('li', class_="created-at")

# %%
created_at = created.find('span', class_='relative-date')['title']

# %%
created_at
# Out:
# 'Nov 18, 2020 9:12 pm'

# %%
last_reply = postStream.find('li', class_="last-reply")
last_reply = last_reply.find('span', class_='relative-date')['title']

# %%
last_reply
# Out:
# 'Nov 19, 2020 10:47 pm'

# %%
replies = postStream.find('li', class_="replies")
nbr_replies = replies.find('span', class_='number').text
nbr_replies
# Out:
# '5'

# %%
views = postStream.find('li', class_="secondary views")
nbr_views = views.find('span', class_='number').text
nbr_views
# Out:
# '78'

# %% [markdown]
# In a post you may not find the replies and views so wrap them in a try-except.

# %%
views.text
# Out:
# '78views'

# %%
likes = postStream.find('li', class_="secondary likes")
try:
    nbr_likes = likes.find('span', class_='number').text
    print(nbr_likes)
except:
    print(0)
# Out:
# 0

# %% [markdown]
# Test for topic tags:

# %%
browser.get('https://forum.flowster.app/t/fba-revenue-calculator-ship-to-amazon/911')
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)

# %%
fulfil_soup = BeautifulSoup(browser.page_source, 'html.parser')
topic_title = fulfil_soup.find_elements_by_class_name('a', class_='fancy-title').text.strip()

# %%
# TODO: A topic can not only have the category but also tags so redo this 
title_wraper = fulfil_soup.find('div', class_='title-wrapper')
#topic_tags = fulfil_soup.find_all('span', class_='category-name')

# %%
topic_tags = title_wraper.find_all('span', class_='category-name')

# %%
topic_tags
# Out:
# [<span class="category-name">Fulfillment</span>,
#  <span class="category-name">Shipping</span>]

# %%
topic_tags = [tag.text for tag in topic_tags]

# %%
topic_tags
# Out:
# ['Fulfillment', 'Shipping']

# %%
topic_category = topic_tags[0]
topic_tags = topic_tags[1:]

# %%
topic_category, topic_tags
# Out:
# ('Fulfillment', ['Shipping'])

# %%
topic_title
# Out:
# 'FBA Revenue Calculator - Ship to Amazon?'

# %% [markdown]
# ## Second run: Defining things up in functions

# %%
from selenium.webdriver import Firefox
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import requests
import time

BASE_URL = 'https://forum.flowster.app'
browse = None

opts = Options()
opts.set_headless()
assert opts.headless # Operating in headless mode
browser = Firefox(options=opts)
browser.get(BASE_URL)

# Get the all the categories names (I believe we don't need this only the links?!) or perhaps it's okay to keep it?
categories = browser.find_elements_by_class_name('category-text-title')

# Get all the categories link 
categ_links = browser.find_elements_by_css_selector('.category > h3 > a')

# Store categories links and names in separate lists
categ_names = []
categ_urls = []
for categ, link in zip(categories, categ_links):
    categ_names.append(categ.text)
    categ_urls.append(link.get_attribute('href'))

# TODO: loop over each category url from categ_urls and get categ_url 
def get_topics_urls(categ_url):
    """
    Get topic URLS for each category
    """
    browser.get(categ_url)
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(3)
    
    categ_topic_soup = BeautifulSoup(browser.page_source, 'html.parser')
    
    categ_topic_links = categ_topic_soup.find_all('a', class_='title raw-link raw-topic-link')
    
    # Get all the topics inside the Product Sourcing category
    categ_topic_urls = []
    
    for topicb_link in categ_topic_links:
        categ_topic_urls.append(BASE_URL + topic_link['href'])
    
    return categ_topic_urls

# TODO: Loop over each categ_topic_urls to get topic_url
def get_topic_soup(topic_url):
    """
    Get current topic_soup
    """
    browser.get(topic_url)
    browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(3)
    topic_soup = BeautifulSoup(browser.page_source, 'html.parser')
    return topic_soup

topic_soup = get_topic_soup(topic_url)

def get_topic_title_tags(topic_soup):
    """
    Get topic title
    """
    topic_title = topic_soup.find('a', class_='fancy-title').text.strip()
    
    title_wraper = topic_soup.find('div', class_='title-wrapper')
    
    topic_tags = title_wraper.find_all('span', class_='category-name')
    topic_tags = [tag.text for tag in topic_tags]
    topic_tags = topic_tags[1:]
    
    topic_category = topic_tags[0]
    
    return topic_title, topic_category, topic_tags
    
def get_topic_comments(topic_soup):
    """
    Get topic leading post and its replies.
    """
    postsDivs = postStream.find_all('div', {'class': ['topic-post clearfix topic-owner regular', 'topic-post clearfix regular']})

    comments = []
    for i in range(len(postsDivs)):
        comment = postsDivs[i].find('div', class_='cooked').text
        #postsDivs[i].find('div', class_='cooked').text.replace('\n', ' ')
        comments.append(comment)

    leading_comment = comments[0]
    if len(comments) == 1:
        other_comments = []
    else:
        other_comments = comments[1:]
    
    return leading_comment, other_comments

def get_topic_created_at(topic_soup):
    """
    Get the topic creation date
    """
    created = topic_soup.find('li', class_="created-at")
    created_at = created.find('span', class_='relative-date')['title']
    if created_at == None:
        return str(0)
    return created_at


def get_topic_replies_nbr(topic_soup):
    """
    Get the topic's nbr of replies
    """    
    replies = topic_soup.find('li', class_="replies")
    nbr_replies = replies.find('span', class_='number').text
    if nbr_replies == None:
        return str(0)
    return nbr_replies

def get_topic_views_nbr(topic_soup):
    """
    Get the topic's nbr of views
    """ 
    views = topic_soup.find('li', class_="secondary views")
    nbr_views = views.find('span', class_='number').text
    if nbr_views == None:
        return str(0)
    return nbr_views

def get_topic_likes_nbr(topic_soup):
    """
    Get the topic's nbr of likes
    """ 
    likes = topic_soup.find('li', class_="secondary likes")
    nbr_likes = likes.find('span', class_='number').text
    if nbr_likes == None:
        return str(0)
    return nbr_likes

# %% [markdown]
# ## Third run: Wraping everything up in a Class

# %%
browser.close()

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.1.5-cp38-cp38-macosx_10_9_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 1.3 MB/s eta 0:00:01    |███████████▏                    | 3.5 MB 1.2 MB/s eta 0:00:06     |█████████████████▋              | 5.5 MB 1.3 MB/s eta 0:00:04     |██████████████████▋             | 5.9 MB 1.3 MB/s eta 0:00:04
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/anaconda3/lib/python3.8/site-packages (from pandas) (2.8.1)
# Collecting numpy>=1.15.4
#   Downloading numpy-1.19.4-cp38-cp38-macosx_10_9_x86_64.whl (15.3 MB)
#      |████████████████████████████████| 15.3 MB 1.3 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Collecting pytz>=2017.2
#   Downloading pytz-2020.4-py2.py3-none-any.whl (509 kB)
#      |████████████████████████████████| 509 kB 1.2 MB/s eta 0:00:01
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.19.4 pandas-1.1.5 pytz-2020.4

# %%
from selenium.webdriver import Firefox
from selenium.webdriver.firefox.options import Options
from bs4 import BeautifulSoup
import requests
import time
import pandas as pd
import json

# %% [markdown]
# **Comments:** Run the following code cell in terminal and not in jupyter notebooks because the `__file__` doesn't run here (it's a shell method.
#
# Source : https://stackoverflow.com/questions/21005822/what-does-os-path-abspathos-path-joinos-path-dirname-file-os-path-pardir
#
# That is a clever way to refer to paths regardless of the script location. The cryptic line you're referring is:
#
# ```
# os.path.abspath(os.path.join(os.path.dirname(__file__), os.path.pardir))
# ```
#
# There are 3 methods and a 2 constants present:
# - `abspath` returns absolute path of a path
# - `join` join to path strings
# - `dirname` returns the directory of a file
# - `__file__` refers to the script's file name
# - `pardir` returns the representation of a parent directory in the OS (usually ..)
#
# Thus, the expression returns the full path name of the executing script in a multiplatform-safe way. No need to hardwire any directions, that's why it is so useful.
#
# There might be other approaches to get a parent directory of where a file is located, for example, programs have the concept of current working directory, os.getcwd(). So doing os.getcwd()+'/..' might work. But this is very dangerous, because working directories can be changed.
#
# Also, if the file is intended to be imported, the working directory will point to the importing file, not the importee, but __file__ always points to the actual module's file so it is safer.
#
# Hope this helps!
#
# Edit: P.S. - Python 3 greatly simplifies this situation by letting us treat paths in an object-oriented manner, so the above line becomes:
#
# from pathlib import Path
# Path(__file__).resolve().parent.parent

# %%
# Access the main link

from selenium.webdriver import Firefox
from selenium.webdriver.firefox.options import Options

BASE_URL = 'https://forum.flowster.app'

opts = Options()
opts.set_headless()
assert opts.headless # Operating in headless mode
browser = Firefox(options=opts)
browser.get(BASE_URL)

# Get the all the categories names (I believe we don't need this only the links?!) or perhaps it's okay to keep it?
categories = browser.find_elements_by_class_name('category-text-title')

# Get all the categories link 
categ_links = browser.find_elements_by_css_selector('.category > h3 > a')

# Store categories links and names in separate lists
categ_names = []
categ_urls = []
for categ, link in zip(categories, categ_links):
    categ_names.append(categ.text)
    categ_urls.append(link.get_attribute('href'))
    
# Access each category to get its topics etc
import requests
import time

SEC_URL = categ_urls[1]
#page = requests.get(SEC_URL)
browser.get(SEC_URL)
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)

from bs4 import BeautifulSoup

soup = BeautifulSoup(browser.page_source, 'html.parser')

ps_topic_links = soup.find_all('a', class_='title raw-link raw-topic-link')

# Get all the topics inside the Product Sourcing category
ps_topic_urls = []
for topic_link in ps_topic_links:
    ps_topic_urls.append(BASE_URL + topic_link['href'])

# Access one of the topic URLS and get the comments and info about it from main post
PS_URL0 = ps_topic_urls[1]
browser.get(PS_URL0)
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)

ps_soup = BeautifulSoup(browser.page_source, 'html.parser')
topic_title = ps_soup.find('a', class_='fancy-title').text.strip()

# DONE: A topic can not only have the category but also tags so redo this 
# BEFORE: topic_category = ps_soup.find('span', class_='category-name').text.strip()

# MERGE with topic title
browser.get('https://forum.flowster.app/t/fba-revenue-calculator-ship-to-amazon/911')# replace url with topic_url
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")
time.sleep(3)

fulfil_soup = BeautifulSoup(browser.page_source, 'html.parser')
topic_title = fulfil_soup.find_elements_by_class_name('a', class_='fancy-title').text.strip()

title_wraper = fulfil_soup.find('div', class_='title-wrapper')
topic_tags = title_wraper.find_all('span', class_='category-name')
topic_tags = [tag.text for tag in topic_tags]
topic_category = topic_tags[0]
topic_tags = topic_tags[1:]
return topic_category, topic_tags


# Get the actual comments
postsDivs = postStream.find_all('div', {'class': ['topic-post clearfix topic-owner regular', 'topic-post clearfix regular']})

comments = []
for i in range(len(postsDivs)):
    comment = postsDivs[i].find('div', class_='cooked').text
    #postsDivs[i].find('div', class_='cooked').text.replace('\n', ' ')
    comments.append(comment)

leading_comment = comments[0]
if len(comments) == 1:
    other_comments = []
else:
    other_comments = comments[1:]

# Get the other info like : likes, views, etc
created = postStream.find('li', class_="created-at")
created_at = created.find('span', class_='relative-date')['title']

last_reply = postStream.find('li', class_="last-reply")
last_reply = last_reply.find('span', class_='relative-date')['title']

replies = postStream.find('li', class_="replies")
nbr_replies = replies.find('span', class_='number').text

views = postStream.find('li', class_="secondary views")
nbr_views = views.find('span', class_='number').text

likes = postStream.find('li', class_="secondary likes")

# Some posts may not actually have likes or views or etc so we should handle it.
try:
    nbr_likes = likes.find('span', class_='number').text
    print(nbr_likes)
except:
    print(0)

# %% [markdown]
# # Explore the scraped data

# %%
import pandas as pd

data = pd.read_csv('FLOWSTER_SCRAPED_DATA20201212224954.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                                    Topic Title  \
# 0           0  About the Store & Website Management category
# 1           1                Securing long term partnerships
# 2           2                           Amazon Free Products
# 3           3            About the Product Sourcing Category
# 4           4       Virtual Assistant sending Emails Hubspot
#
#                      Category Tags  \
# 0  Store & Website Management   []
# 1  Store & Website Management   []
# 2  Store & Website Management   []
# 3            Product Sourcing   []
# 4            Product Sourcing   []
#
#                                         Leading Post  \
# 0  Have questions about Store & Website Managemen...
# 1  Hello, I just closed a deal to manage a quite ...
# 2  Hello,\nI need some buyers for my products in ...
# 3  Have questions about sourcing products? This i...
# 4  Hello Bright Ideas Tribe,\nI would like to giv...
#
#                                         Post Replies            Created_at  \
# 0                                                 []                     0
# 1  ['Brand management is going to have partner tu...   Dec 5, 2020 5:49 pm
# 2                                                 []                     0
# 3                                                 []                     0
# 4  ['\n\n\nknowledge.hubspot.com 1\n\n\n\nCreate ...  Nov 18, 2020 9:12 pm
#
#    Likes  Views  Replies
# 0      0      0        0
# 1      0     19        1
# 2      0      0        0
# 3      0      0        0
# 4      0     81        5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    278 non-null    int64
#  1   Topic Title   278 non-null    object
#  2   Category      278 non-null    object
#  3   Tags          278 non-null    object
#  4   Leading Post  277 non-null    object
#  5   Post Replies  278 non-null    object
#  6   Created_at    278 non-null    object
#  7   Likes         278 non-null    int64
#  8   Views         278 non-null    int64
#  9   Replies       278 non-null    int64
# dtypes: int64(4), object(6)
# memory usage: 21.8+ KB

# %%
data['Leading Post'][1]
# Out:
# 'Hello, I just closed a deal to manage a quite large brand account on Amazon, my main concern now is that this partnership may only last 1-2 years and once the account has grown to higher levels they would just manage it by themselves. What methods, tips and tricks you can suggest to protect this deal and make sure they will stick with my company managing their account for long term? Essentially how can I make them dependent on me so it will be very hard for them to let go our partnership?'

# %%
all_categ = data['Category'].unique()

# %%
all_categ
# Out:
# array(['Store & Website Management', 'Product Sourcing', 'Management',
#        'Amazon Specific', 'Fulfillment', 'Flowster-specific',
#        'eCommerce Marketplaces', 'Traffic Sources', 'Software & Tools',
#        'Financial Management', 'Human Resources', 'Misc Topics'],
#       dtype=object)

# %%
len(all_categ)
# Out:
# 12

# %% [markdown]
# ## Resources for EDA (Exploratory Data Analysis)

# %% [markdown]
# Check out these two resources and the ones in module for further info and methods:
# - https://www.analyticsvidhya.com/blog/2020/04/beginners-guide-exploratory-data-analysis-text-data/
# - `Processing Textual Data.ipynb`
